# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from collections import defaultdict
from matplotlib.animation import FuncAnimation, PillowWriter, FFMpegWriter
import os

# %%
class Vehicle:
    _id_counter = 0
    """Define vehicle attributes and rules to be implemented"""
    def __init__(self, x_position, speed, max_speed, length, width, road_designation, vehicle_type, current_row, lane_changing_prob):
        self.vehicle_id = Vehicle._id_counter  # Assign a unique ID to each vehicle
        Vehicle._id_counter += 1  #Increment the counter for the next vehicle
        self.x_position = x_position #position along the length of the road (x position)
        self.speed = speed #number of cells the vehicle will move per timestep
        self.max_speed = max_speed #maximum speed
        self.braking_prob = 0.01 #probability of random slowdown
        self.length = length #length of the vehicle is the number of cells the vehicle occupies along the length of the road
        self.width = width #width of the vehicle is the number of cells the vehicle occupies along the width of the road
        self.road_designation = road_designation #whether inside or outside
        self.vehicle_type = vehicle_type #type of vehicle is determined by the size and behavior
        self.current_row = current_row #also known as the y position of the right side of the vehicle
        self.lane_changing_prob = lane_changing_prob #probability that a vehicle will transfer lane
        
        
    def accelerate(self):
        """Increases vehicle's speed by 1 cell, up to the maximum speed"""
        if self.speed < self.max_speed:
            self.speed += 1

    def gap_distance(self, vehicle_row_to_be_checked): 
        """Debugging this - make gap distance consider toroidal boundary cond. recently introduced"""
        """vehicle row to be checked: Input is row 0, you check for lane 1(row 0 and 1). Input is row 1, you check for lane at the middle (row 1 and 2). Input is row 2, you check for lane 2(rows 2 and 3)."""
        rear_bumper_position = self.x_position
        print(f"{self.vehicle_type} {self.vehicle_id}'s rear bumper is at {rear_bumper_position}")
        front_bumper_position = rear_bumper_position + self.length - 1
        print(f"{self.vehicle_type} {self.vehicle_id}'s front bumper is at {front_bumper_position}")
        max_distance = self.speed #maximum distance checked is equivalent to speed
        print(f"{self.vehicle_type} {self.vehicle_id}'s maximum distance is  {max_distance}")
        road_length = self.road_designation.road_length
        print(f"{self.vehicle_type} {self.vehicle_id}'s road has length of {road_length}")
        
        gap_distance = max_distance
        print(f"{self.vehicle_type} {self.vehicle_id}: default gap distance is {gap_distance}")
        '''gap_distance_row_2 = max_distance
        print(f"{self.vehicle_type} {self.vehicle_id}: gap distance of left row is {gap_distance_row_2}")'''
        
        for distance in range(1, max_distance + 1):
            start_of_space_to_be_checked = (front_bumper_position + distance)  % road_length
            print(f"{self.vehicle_type} {self.vehicle_id}: At the current speed, we are checking position {start_of_space_to_be_checked} row {self.current_row} to {self.current_row + 1} ")
            end_of_space_to_be_checked = (front_bumper_position + max_distance)  % road_length #We have to include the front bumper position, to avoid vehicle overlaps
            print(f"{self.vehicle_type} {self.vehicle_id}: At the current speed, we check until position {end_of_space_to_be_checked}")
            
            # Check if there's an occupied space within the distance
            if start_of_space_to_be_checked < end_of_space_to_be_checked:
                print(f"Checking occupancy at position {start_of_space_to_be_checked} in row {vehicle_row_to_be_checked} to row {vehicle_row_to_be_checked + 1}")
                print(self.road_designation.road_occupancy[start_of_space_to_be_checked, vehicle_row_to_be_checked:vehicle_row_to_be_checked + self.width])
                if np.sum(self.road_designation.road_occupancy[start_of_space_to_be_checked, vehicle_row_to_be_checked:vehicle_row_to_be_checked + self.width]) != 0:
                    gap_distance = distance - 1
                    break
                    print(f" The gap distance of {self.vehicle_type} {self.vehicle_id} is {gap_distance}")
            else:  # Wrap-around case
                print(f"Checking occupancy wrap-around at position {start_of_space_to_be_checked} in row {vehicle_row_to_be_checked} to row {vehicle_row_to_be_checked + 1}")
                print(self.road_designation.road_occupancy[start_of_space_to_be_checked, vehicle_row_to_be_checked:vehicle_row_to_be_checked + self.width])
                #print(self.road_designation.road_occupancy[:end_of_space_to_be_checked + 1, vehicle_row_to_be_checked:vehicle_row_to_be_checked + self.width])
                if np.sum(self.road_designation.road_occupancy[start_of_space_to_be_checked, vehicle_row_to_be_checked:vehicle_row_to_be_checked + self.width]) != 0: #or \
                   #np.sum(self.road_designation.road_occupancy[:end_of_space_to_be_checked + 1, vehicle_row_to_be_checked:vehicle_row_to_be_checked + self.width]) != 0:
                    gap_distance = distance - 1
                    break
                    print(f" The gap distance of {self.vehicle_type} {self.vehicle_id} is {gap_distance}")
                    
        '''for distance in range(1, max_distance + 1):
            next_rear_bumper_position = (rear_bumper_position + distance) % road_length
            next_front_bumper_position = (front_bumper_position + distance) % road_length

            if next_rear_bumper_position < next_front_bumper_position:
                if np.sum(self.road_designation.road_occupancy[next_rear_bumper_position:next_front_bumper_position, vehicle_row_to_be_checked+1]) != 0:
                    gap_distance_row_2 = distance - 1
                    print(f"The gap distance on row {self.current_row + 1} is {gap_distance_row_2}.")
                    break
            else:  # Wrap-around case
                if np.sum(self.road_designation.road_occupancy[next_rear_bumper_position:, vehicle_row_to_be_checked+1]) != 0 or \
                   np.sum(self.road_designation.road_occupancy[:next_front_bumper_position, vehicle_row_to_be_checked+1]) != 0:
                    gap_distance_row_2 = distance - 1
                    print(f"The gap distance on row {self.current_row + 1} is {gap_distance_row_2}.")
                    break'''
                
        #if min(gap_distance_row_1, gap_distance_row_2) < 0: #For debugging
            #print(gap_distance_row_1, gap_distance_row_2, current_x_position) #Results to negative headway distance
        #print(min(gap_distance_row_1, gap_distance_row_2))
        return gap_distance # Return the  gap distance

    def lane_changing(self):
        """attempts to change lanes based on vehicle type and lane availability
        Here, we define a lane as a space of 2 cells wide. We assume a two-lane road(4 cells wide).
        We assume that each half lane is an array, imagine a vertical stack of arrays, indexing is 0 to 4 (bottom to top). Right side is the bottom."""
        new_row = self.current_row #by default, vehicle stays on its lane
        gap_distance_of_own_lane = self.gap_distance(self.current_row) #obtains the gap distance of current lane
        print(f"{self.vehicle_type}{self.vehicle_id} has a gap distance of {gap_distance_of_own_lane}")
        gap_distance_of_adjacent_right_lane = self.gap_distance(self.current_row - 1) if self.current_row > 0 else gap_distance_of_own_lane
        print(f" The right row(and its corresponding lane) of {self.vehicle_type} {self.vehicle_id} has an available space of {gap_distance_of_adjacent_right_lane} cells.")
        gap_distance_of_adjacent_left_lane = self.gap_distance(self.current_row + 1) if self.current_row < 2 else gap_distance_of_own_lane
        print(f" The left row(and its corresponding lane) of {self.vehicle_type} {self.vehicle_id} has an available space of {gap_distance_of_adjacent_left_lane} cells.")
        if self.speed > gap_distance_of_own_lane:
            if self.current_row == 0 and gap_distance_of_adjacent_left_lane > gap_distance_of_own_lane:#There are specific cases wherein changing to the right or left lane is possible/legal
                new_row = self.current_row + 1
                print(f" Vehicle {self.vehicle_id} in row {self.current_row} switches to row {new_row}")
            elif self.current_row == 2 and gap_distance_of_adjacent_right_lane>gap_distance_of_own_lane: 
                new_row = self.current_row - 1
                print(f" Vehicle {self.vehicle_id} in row {self.current_row} switches to row {new_row}")
            elif self.current_row == 1 and gap_distance_own_lane < max(gap_distance_of_adjacent_right_lane, gap_distance_of_adjacent_left_lane):
                if gap_distance_of_adjacent_right_lane > gap_distance_of_adjacent_left_lane:
                    new_row = self.current_row - 1
                    print(f" Vehicle {self.vehicle_id} in row {self.current_row} switches to row {new_row}")
                elif gap_distance_of_adjacent_right_lane < gap_distance_of_adjacent_left_lane:
                    new_row = self.current_row + 1
                    print(f" Vehicle {self.vehicle_id} in row {self.current_row} switches to row {new_row}")
        # Check for space on the new lane
        if self.road_designation.road_occupancy[self.x_position:self.x_position + self.length, new_row:new_row + self.width].sum() == 0:
            self.current_row = new_row

        #For debugging:
        if self.speed < gap_distance_of_own_lane:
            print(vehicle.gap_distance, gap_distance_of_own_lane, vehicle.speed)
        if gap_distance_of_own_lane < 0:
            print(f"{self.vehicle_type} {vehicle.vehicle_id} invalid")

    def decelerate(self):
        """decreases vehicle's speed to match the gap distance, given the speed>gap distance"""
        gap_distance_of_own_lane = self.gap_distance(self.current_row)
        if self.speed > gap_distance_of_own_lane:
            self.speed = gap_distance_of_own_lane
            print(f"{self.vehicle_type} {self.vehicle_id} is decelerating on own lane")

    def braking(self):
        """Mimics random slowdown, randomly decreases vehicle's speed based on braking probability """
        if np.random.rand() < self.braking_prob and self.speed > 0:
            self.speed -= 1
            print(f"{self.vehicle_type} {self.vehicle_id} is braking")


    def move(self):
        """implements movement"""
        new_position = (self.x_position + self.speed) % self.road_designation.road_length
        self.x_position = new_position

# %%
class Road:
    def __init__(self, road_length, road_width, speed_limit):
        self.road_length = road_length
        self.road_width = road_width
        self.speed_limit = speed_limit
        self.road_occupancy = np.zeros((road_length, road_width))

# %%
class IntraRoadSimulator:
    def __init__(self, road):
        """This method stores the input agents and initializes output data"""
        self.road = road  # Store the road instance
        self.vehicles = []  # List to store vehicle instances
        self.occupancy_history = []  # List to store the history of road occupancy states
        #self.vehicle_throughput = 0

    def update_occupancy(self):
        """This method updates road occupancy based on vehicle position and length"""
        self.road.road_occupancy.fill(0)
        for vehicle in self.vehicles:
            x_start = vehicle.x_position
            x_end = (vehicle.x_position + vehicle.length) % self.road.road_length #from vehicle rear bumper(position|) to front, minus 1. takes account of toroidal boundaries
            y_start = vehicle.current_row
            y_end = min(vehicle.current_row + vehicle.width, self.road.road_width)
            if x_start < x_end:
                if vehicle.vehicle_type == "jeep":
                    self.road.road_occupancy[x_start:x_end, y_start:y_end] = 1
                else:
                    self.road.road_occupancy[x_start:x_end, y_start:y_end] = 2
            else:
                if vehicle.vehicle_type == "jeep":
                    self.road.road_occupancy[x_start:, y_start:y_end] = 1
                    self.road.road_occupancy[:x_end, y_start:y_end] = 1
                else:
                    self.road.road_occupancy[x_start:, y_start:y_end] = 2
                    self.road.road_occupancy[:x_end, y_start:y_end] = 2
        self.occupancy_history.append(self.road.road_occupancy.copy())

    '''def initialize_vehicles(self, density, truck_fraction, truck_lane_change_prob, jeep_lane_change_prob):
        A, B = 7 * 2, 3 * 2  # Constants for truck and jeep area
        L, W = self.road.road_length, self.road.road_width  # Road dimensions
        N = int(density * L * W * (truck_fraction / A + (1 - truck_fraction) / B))  # Number of vehicles based on density and truck fraction
        for _ in range(N):
            vehicle_type = 'truck' if np.random.rand() < truck_fraction else 'jeep'  # Randomly decide vehicle type
            length = 7 if vehicle_type == 'truck' else 3
            width = 2
            x_position = np.random.randint(0, self.road.road_length)  # Random initial position
            speed = np.random.randint(1, self.road.speed_limit + 1)
            lane_changing_prob = truck_lane_change_prob if vehicle_type == 'truck' else jeep_lane_change_prob
            current_row = 2 if vehicle_type == 'truck' else 0
            if self.road.road_occupancy[x_position:x_position + length, current_row:current_row + width].sum() == 0: # is the road portion empty?
                new_vehicle = Vehicle(x_position, speed, self.road.speed_limit, length, width, self.road, vehicle_type, current_row, lane_changing_prob)
                self.vehicles.append(new_vehicle)  # Add vehicle to the list
                if new_vehicle.vehicle_type == "jeep":
                    self.road.road_occupancy[x_position:x_position + length, current_row:current_row + width] = 1
                else:
                    self.road.road_occupancy[x_position:x_position + length, current_row:current_row + width] = 2 # Mark vehicle position on road occupancy grid'''
                        
    def initialize_vehicles(self, density, truck_fraction, truck_lane_change_prob, jeep_lane_change_prob):
        A, B = 7 * 2, 3 * 2  # Constants for truck and jeep area
        L, W = self.road.road_length, self.road.road_width  # Road dimensions
        N = int(density * L * W * (truck_fraction / A + (1 - truck_fraction) / B))  # Number of vehicles based on density and truck fraction
        for _ in range(int(N*truck_fraction)):
            vehicle_type = 'truck'
            length = 7
            width = 2
            x_position = np.random.randint(0, self.road.road_length)  # Random initial position
            speed = np.random.randint(1, self.road.speed_limit + 1)
            lane_changing_prob = truck_lane_change_prob
            current_row = 2 
            if self.road.road_occupancy[x_position:x_position + length, current_row:current_row + width].sum() == 0: # is the road portion empty?
                new_vehicle = Vehicle(x_position, speed, self.road.speed_limit, length, width, self.road, vehicle_type, current_row, lane_changing_prob)
                self.vehicles.append(new_vehicle)  # Add vehicle to the list
                self.road.road_occupancy[x_position:x_position + length, current_row:current_row + width] = 2
        for _ in range(int(N*(1-truck_fraction))):
            vehicle_type = 'jeep'  # Randomly decide vehicle type
            length = 3
            width = 2
            x_position = np.random.randint(0, self.road.road_length)  # Random initial position
            speed = np.random.randint(1, self.road.speed_limit + 1)
            lane_changing_prob = jeep_lane_change_prob
            current_row = 0 
            if self.road.road_occupancy[x_position:x_position + length, current_row:current_row + width].sum() == 0: # is the road portion empty?
                new_vehicle = Vehicle(x_position, speed, self.road.speed_limit, length, width, self.road, vehicle_type, current_row, lane_changing_prob)
                self.vehicles.append(new_vehicle)  # Add vehicle to the list
                self.road.road_occupancy[x_position:x_position + length, current_row:current_row + width] = 1

    def simulation_step(self):
        np.random.shuffle(self.vehicles)
        for vehicle in self.vehicles:
            print(f" {vehicle.vehicle_type} {vehicle.vehicle_id} attributes")
            vehicle.accelerate()  # Accelerate the vehicle
            print(f"ACCELERATE DEBUGGER: {vehicle.vehicle_type} {vehicle.vehicle_id} want to move at a speed of {vehicle.speed}")
            if np.random.rand() < vehicle.lane_changing_prob:
                vehicle.lane_changing()  # Change lane if possible
                vehicle.decelerate() # Decelerate if necessary
            else:
                vehicle.decelerate()  # Decelerate if not changing lanes
            # Apply brakes
            vehicle.braking()    
            """if vehicle.x_position == self.road.road_length - vehicle.length: #Greatest fix: redundant +speed and -length on position and road length sides, respectively
                #print(f"Vehicle {vehicle.vehicle_id} reached end of road at position {vehicle.x_position}")
                self.record_throughput(vehicle)"""
            #self.update_occupancy()
            print(f"BEFORE MOVE DEBUGGER: {vehicle.vehicle_type} {vehicle.vehicle_id} is at position {vehicle.x_position}")
            vehicle.move()  # Move the vehicle
            print(f"AFTER MOVE DEBUGGER: {vehicle.vehicle_type} {vehicle.vehicle_id} is at position {vehicle.x_position}, with a speed of {vehicle.speed} at row {vehicle.current_row}")
            

        self.update_occupancy()  # Update the road occupancy grid
        
    def visualize(self, step_count):
        plt.figure(figsize=(20, 6))
        plt.imshow(self.road.road_occupancy.T, cmap='gray_r', origin='lower')
        plt.title(f'Step {step_count}')
        plt.xlabel('Road Length')
        plt.ylabel('Lane')
        plt.xticks(range(0, self.road.road_length + 1, 1))
        plt.yticks(range(0, self.road.road_width + 1, 1))
        plt.tight_layout()
        plt.show()

# %% [markdown]
# STATIC CHECKER

# %%
road = Road(road_length=100, road_width=4, speed_limit=5)
simulator = IntraRoadSimulator(road)

density = 1  # Example density
truck_fraction = 0.3 # Example truck fraction
timesteps = 10
simulator.initialize_vehicles(density, truck_fraction, 0.3, 0)
for step in range(timesteps):
    simulator.simulation_step()
    if step % 1 == 0:
        simulator.visualize(step)
# Out:
#  jeep 23 attributes
# ACCELERATE DEBUGGER: jeep 23 want to move at a speed of 4
# jeep 23's rear bumper is at 89
# jeep 23's front bumper is at 91
# jeep 23's maximum distance is  4
# jeep 23's road has length of 100
# jeep 23: default gap distance is 4
# jeep 23: At the current speed, we are checking position 92 row 0 to 1
# jeep 23: At the current speed, we check until position 95
# Checking occupancy at position 92 in row 0 to row 1
# [0. 0.]
# jeep 23: At the current speed, we are checking position 93 row 0 to 1
# jeep 23: At the current speed, we check until position 95
# Checking occupancy at position 93 in row 0 to row 1
# [0. 0.]
# jeep 23: At the current speed, we are checking position 94 row 0 to 1
# jeep 23: At the current speed, we check until position 95
# Checking occupancy at position 94 in row 0 to row 1
# [0. 0.]
# jeep 23: At the current speed, we are checking position 95 row 0 to 1
# jeep 23: At the current speed, we check until position 95
# Checking occupancy wrap-around at position 95 in row 0 to row 1
# [1. 1.]
# jeep 23 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 23 is at position 89
# AFTER MOVE DEBUGGER: jeep 23 is at position 92, with a speed of 3 at row 0
#  jeep 29 attributes
# ACCELERATE DEBUGGER: jeep 29 want to move at a speed of 3
# jeep 29's rear bumper is at 18
# jeep 29's front bumper is at 20
# jeep 29's maximum distance is  3
# jeep 29's road has length of 100
# jeep 29: default gap distance is 3
# jeep 29: At the current speed, we are checking position 21 row 0 to 1
# jeep 29: At the current speed, we check until position 23
# Checking occupancy at position 21 in row 0 to row 1
# [1. 1.]
# jeep 29 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 29 is at position 18
# AFTER MOVE DEBUGGER: jeep 29 is at position 18, with a speed of 0 at row 0
#  jeep 41 attributes
# ACCELERATE DEBUGGER: jeep 41 want to move at a speed of 2
# jeep 41's rear bumper is at 62
# jeep 41's front bumper is at 64
# jeep 41's maximum distance is  2
# jeep 41's road has length of 100
# jeep 41: default gap distance is 2
# jeep 41: At the current speed, we are checking position 65 row 0 to 1
# jeep 41: At the current speed, we check until position 66
# Checking occupancy at position 65 in row 0 to row 1
# [0. 0.]
# jeep 41: At the current speed, we are checking position 66 row 0 to 1
# jeep 41: At the current speed, we check until position 66
# Checking occupancy wrap-around at position 66 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 41 is at position 62
# AFTER MOVE DEBUGGER: jeep 41 is at position 64, with a speed of 2 at row 0
#  jeep 35 attributes
# ACCELERATE DEBUGGER: jeep 35 want to move at a speed of 5
# jeep 35's rear bumper is at 74
# jeep 35's front bumper is at 76
# jeep 35's maximum distance is  5
# jeep 35's road has length of 100
# jeep 35: default gap distance is 5
# jeep 35: At the current speed, we are checking position 77 row 0 to 1
# jeep 35: At the current speed, we check until position 81
# Checking occupancy at position 77 in row 0 to row 1
# [0. 0.]
# jeep 35: At the current speed, we are checking position 78 row 0 to 1
# jeep 35: At the current speed, we check until position 81
# Checking occupancy at position 78 in row 0 to row 1
# [0. 0.]
# jeep 35: At the current speed, we are checking position 79 row 0 to 1
# jeep 35: At the current speed, we check until position 81
# Checking occupancy at position 79 in row 0 to row 1
# [0. 0.]
# jeep 35: At the current speed, we are checking position 80 row 0 to 1
# jeep 35: At the current speed, we check until position 81
# Checking occupancy at position 80 in row 0 to row 1
# [0. 0.]
# jeep 35: At the current speed, we are checking position 81 row 0 to 1
# jeep 35: At the current speed, we check until position 81
# Checking occupancy wrap-around at position 81 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 35 is at position 74
# AFTER MOVE DEBUGGER: jeep 35 is at position 79, with a speed of 5 at row 0
#  jeep 26 attributes
# ACCELERATE DEBUGGER: jeep 26 want to move at a speed of 5
# jeep 26's rear bumper is at 4
# jeep 26's front bumper is at 6
# jeep 26's maximum distance is  5
# jeep 26's road has length of 100
# jeep 26: default gap distance is 5
# jeep 26: At the current speed, we are checking position 7 row 0 to 1
# jeep 26: At the current speed, we check until position 11
# Checking occupancy at position 7 in row 0 to row 1
# [0. 0.]
# jeep 26: At the current speed, we are checking position 8 row 0 to 1
# jeep 26: At the current speed, we check until position 11
# Checking occupancy at position 8 in row 0 to row 1
# [1. 1.]
# jeep 26 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 26 is at position 4
# AFTER MOVE DEBUGGER: jeep 26 is at position 5, with a speed of 1 at row 0
#  truck 17 attributes
# ACCELERATE DEBUGGER: truck 17 want to move at a speed of 5
# truck 17's rear bumper is at 70
# truck 17's front bumper is at 76
# truck 17's maximum distance is  5
# truck 17's road has length of 100
# truck 17: default gap distance is 5
# truck 17: At the current speed, we are checking position 77 row 2 to 3
# truck 17: At the current speed, we check until position 81
# Checking occupancy at position 77 in row 2 to row 3
# [2. 2.]
# truck 17 is decelerating on own lane
# BEFORE MOVE DEBUGGER: truck 17 is at position 70
# AFTER MOVE DEBUGGER: truck 17 is at position 70, with a speed of 0 at row 2
#  truck 19 attributes
# ACCELERATE DEBUGGER: truck 19 want to move at a speed of 3
# truck 19's rear bumper is at 84
# truck 19's front bumper is at 90
# truck 19's maximum distance is  3
# truck 19's road has length of 100
# truck 19: default gap distance is 3
# truck 19: At the current speed, we are checking position 91 row 2 to 3
# truck 19: At the current speed, we check until position 93
# Checking occupancy at position 91 in row 2 to row 3
# [0. 0.]
# truck 19: At the current speed, we are checking position 92 row 2 to 3
# truck 19: At the current speed, we check until position 93
# Checking occupancy at position 92 in row 2 to row 3
# [0. 0.]
# truck 19: At the current speed, we are checking position 93 row 2 to 3
# truck 19: At the current speed, we check until position 93
# Checking occupancy wrap-around at position 93 in row 2 to row 3
# [0. 0.]
# BEFORE MOVE DEBUGGER: truck 19 is at position 84
# AFTER MOVE DEBUGGER: truck 19 is at position 87, with a speed of 3 at row 2
#  jeep 39 attributes
# ACCELERATE DEBUGGER: jeep 39 want to move at a speed of 3
# jeep 39's rear bumper is at 28
# jeep 39's front bumper is at 30
# jeep 39's maximum distance is  3
# jeep 39's road has length of 100
# jeep 39: default gap distance is 3
# jeep 39: At the current speed, we are checking position 31 row 0 to 1
# jeep 39: At the current speed, we check until position 33
# Checking occupancy at position 31 in row 0 to row 1
# [0. 0.]
# jeep 39: At the current speed, we are checking position 32 row 0 to 1
# jeep 39: At the current speed, we check until position 33
# Checking occupancy at position 32 in row 0 to row 1
# [1. 1.]
# jeep 39 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 39 is at position 28
# AFTER MOVE DEBUGGER: jeep 39 is at position 29, with a speed of 1 at row 0
#  truck 22 attributes
# ACCELERATE DEBUGGER: truck 22 want to move at a speed of 4
# truck 22's rear bumper is at 34
# truck 22's front bumper is at 40
# truck 22's maximum distance is  4
# truck 22's road has length of 100
# truck 22: default gap distance is 4
# truck 22: At the current speed, we are checking position 41 row 2 to 3
# truck 22: At the current speed, we check until position 44
# Checking occupancy at position 41 in row 2 to row 3
# [2. 2.]
# truck 22 is decelerating on own lane
# BEFORE MOVE DEBUGGER: truck 22 is at position 34
# AFTER MOVE DEBUGGER: truck 22 is at position 34, with a speed of 0 at row 2
#  jeep 34 attributes
# ACCELERATE DEBUGGER: jeep 34 want to move at a speed of 4
# jeep 34's rear bumper is at 95
# jeep 34's front bumper is at 97
# jeep 34's maximum distance is  4
# jeep 34's road has length of 100
# jeep 34: default gap distance is 4
# jeep 34: At the current speed, we are checking position 98 row 0 to 1
# jeep 34: At the current speed, we check until position 1
# Checking occupancy wrap-around at position 98 in row 0 to row 1
# [0. 0.]
# jeep 34: At the current speed, we are checking position 99 row 0 to 1
# jeep 34: At the current speed, we check until position 1
# Checking occupancy wrap-around at position 99 in row 0 to row 1
# [1. 1.]
# jeep 34 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 34 is at position 95
# AFTER MOVE DEBUGGER: jeep 34 is at position 96, with a speed of 1 at row 0
#  jeep 38 attributes
# ACCELERATE DEBUGGER: jeep 38 want to move at a speed of 2
# jeep 38's rear bumper is at 14
# jeep 38's front bumper is at 16
# jeep 38's maximum distance is  2
# jeep 38's road has length of 100
# jeep 38: default gap distance is 2
# jeep 38: At the current speed, we are checking position 17 row 0 to 1
# jeep 38: At the current speed, we check until position 18
# Checking occupancy at position 17 in row 0 to row 1
# [0. 0.]
# jeep 38: At the current speed, we are checking position 18 row 0 to 1
# jeep 38: At the current speed, we check until position 18
# Checking occupancy wrap-around at position 18 in row 0 to row 1
# [1. 1.]
# jeep 38 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 38 is at position 14
# AFTER MOVE DEBUGGER: jeep 38 is at position 15, with a speed of 1 at row 0
#  truck 21 attributes
# ACCELERATE DEBUGGER: truck 21 want to move at a speed of 5
# truck 21's rear bumper is at 12
# truck 21's front bumper is at 18
# truck 21's maximum distance is  5
# truck 21's road has length of 100
# truck 21: default gap distance is 5
# truck 21: At the current speed, we are checking position 19 row 2 to 3
# truck 21: At the current speed, we check until position 23
# Checking occupancy at position 19 in row 2 to row 3
# [0. 0.]
# truck 21: At the current speed, we are checking position 20 row 2 to 3
# truck 21: At the current speed, we check until position 23
# Checking occupancy at position 20 in row 2 to row 3
# [0. 0.]
# truck 21: At the current speed, we are checking position 21 row 2 to 3
# truck 21: At the current speed, we check until position 23
# Checking occupancy at position 21 in row 2 to row 3
# [0. 0.]
# truck 21: At the current speed, we are checking position 22 row 2 to 3
# truck 21: At the current speed, we check until position 23
# Checking occupancy at position 22 in row 2 to row 3
# [0. 0.]
# truck 21: At the current speed, we are checking position 23 row 2 to 3
# truck 21: At the current speed, we check until position 23
# Checking occupancy wrap-around at position 23 in row 2 to row 3
# [0. 0.]
# BEFORE MOVE DEBUGGER: truck 21 is at position 12
# AFTER MOVE DEBUGGER: truck 21 is at position 17, with a speed of 5 at row 2
#  truck 18 attributes
# ACCELERATE DEBUGGER: truck 18 want to move at a speed of 4
# truck 18's rear bumper is at 41
# truck 18's front bumper is at 47
# truck 18's maximum distance is  4
# truck 18's road has length of 100
# truck 18: default gap distance is 4
# truck 18: At the current speed, we are checking position 48 row 2 to 3
# truck 18: At the current speed, we check until position 51
# Checking occupancy at position 48 in row 2 to row 3
# [0. 0.]
# truck 18: At the current speed, we are checking position 49 row 2 to 3
# truck 18: At the current speed, we check until position 51
# Checking occupancy at position 49 in row 2 to row 3
# [0. 0.]
# truck 18: At the current speed, we are checking position 50 row 2 to 3
# truck 18: At the current speed, we check until position 51
# Checking occupancy at position 50 in row 2 to row 3
# [0. 0.]
# truck 18: At the current speed, we are checking position 51 row 2 to 3
# truck 18: At the current speed, we check until position 51
# Checking occupancy wrap-around at position 51 in row 2 to row 3
# [0. 0.]
# truck18 has a gap distance of 4
# truck 18's rear bumper is at 41
# truck 18's front bumper is at 47
# truck 18's maximum distance is  4
# truck 18's road has length of 100
# truck 18: default gap distance is 4
# truck 18: At the current speed, we are checking position 48 row 2 to 3
# truck 18: At the current speed, we check until position 51
# Checking occupancy at position 48 in row 1 to row 2
# [0. 0.]
# truck 18: At the current speed, we are checking position 49 row 2 to 3
# truck 18: At the current speed, we check until position 51
# Checking occupancy at position 49 in row 1 to row 2
# [0. 0.]
# truck 18: At the current speed, we are checking position 50 row 2 to 3
# truck 18: At the current speed, we check until position 51
# Checking occupancy at position 50 in row 1 to row 2
# [0. 0.]
# truck 18: At the current speed, we are checking position 51 row 2 to 3
# truck 18: At the current speed, we check until position 51
# Checking occupancy wrap-around at position 51 in row 1 to row 2
# [1. 0.]
#  The right row(and its corresponding lane) of truck 18 has an available space of 3 cells.
#  The left row(and its corresponding lane) of truck 18 has an available space of 4 cells.
# truck 18's rear bumper is at 41
# truck 18's front bumper is at 47
# truck 18's maximum distance is  4
# truck 18's road has length of 100
# truck 18: default gap distance is 4
# truck 18: At the current speed, we are checking position 48 row 2 to 3
# truck 18: At the current speed, we check until position 51
# Checking occupancy at position 48 in row 2 to row 3
# [0. 0.]
# truck 18: At the current speed, we are checking position 49 row 2 to 3
# truck 18: At the current speed, we check until position 51
# Checking occupancy at position 49 in row 2 to row 3
# [0. 0.]
# truck 18: At the current speed, we are checking position 50 row 2 to 3
# truck 18: At the current speed, we check until position 51
# Checking occupancy at position 50 in row 2 to row 3
# [0. 0.]
# truck 18: At the current speed, we are checking position 51 row 2 to 3
# truck 18: At the current speed, we check until position 51
# Checking occupancy wrap-around at position 51 in row 2 to row 3
# [0. 0.]
# BEFORE MOVE DEBUGGER: truck 18 is at position 41
# AFTER MOVE DEBUGGER: truck 18 is at position 45, with a speed of 4 at row 2
#  jeep 30 attributes
# ACCELERATE DEBUGGER: jeep 30 want to move at a speed of 5
# jeep 30's rear bumper is at 38
# jeep 30's front bumper is at 40
# jeep 30's maximum distance is  5
# jeep 30's road has length of 100
# jeep 30: default gap distance is 5
# jeep 30: At the current speed, we are checking position 41 row 0 to 1
# jeep 30: At the current speed, we check until position 45
# Checking occupancy at position 41 in row 0 to row 1
# [0. 0.]
# jeep 30: At the current speed, we are checking position 42 row 0 to 1
# jeep 30: At the current speed, we check until position 45
# Checking occupancy at position 42 in row 0 to row 1
# [1. 1.]
# jeep 30 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 30 is at position 38
# AFTER MOVE DEBUGGER: jeep 30 is at position 39, with a speed of 1 at row 0
#  jeep 25 attributes
# ACCELERATE DEBUGGER: jeep 25 want to move at a speed of 5
# jeep 25's rear bumper is at 21
# jeep 25's front bumper is at 23
# jeep 25's maximum distance is  5
# jeep 25's road has length of 100
# jeep 25: default gap distance is 5
# jeep 25: At the current speed, we are checking position 24 row 0 to 1
# jeep 25: At the current speed, we check until position 28
# Checking occupancy at position 24 in row 0 to row 1
# [0. 0.]
# jeep 25: At the current speed, we are checking position 25 row 0 to 1
# jeep 25: At the current speed, we check until position 28
# Checking occupancy at position 25 in row 0 to row 1
# [0. 0.]
# jeep 25: At the current speed, we are checking position 26 row 0 to 1
# jeep 25: At the current speed, we check until position 28
# Checking occupancy at position 26 in row 0 to row 1
# [0. 0.]
# jeep 25: At the current speed, we are checking position 27 row 0 to 1
# jeep 25: At the current speed, we check until position 28
# Checking occupancy at position 27 in row 0 to row 1
# [0. 0.]
# jeep 25: At the current speed, we are checking position 28 row 0 to 1
# jeep 25: At the current speed, we check until position 28
# Checking occupancy wrap-around at position 28 in row 0 to row 1
# [1. 1.]
# jeep 25 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 25 is at position 21
# AFTER MOVE DEBUGGER: jeep 25 is at position 25, with a speed of 4 at row 0
#  jeep 33 attributes
# ACCELERATE DEBUGGER: jeep 33 want to move at a speed of 5
# jeep 33's rear bumper is at 8
# jeep 33's front bumper is at 10
# jeep 33's maximum distance is  5
# jeep 33's road has length of 100
# jeep 33: default gap distance is 5
# jeep 33: At the current speed, we are checking position 11 row 0 to 1
# jeep 33: At the current speed, we check until position 15
# Checking occupancy at position 11 in row 0 to row 1
# [0. 0.]
# jeep 33: At the current speed, we are checking position 12 row 0 to 1
# jeep 33: At the current speed, we check until position 15
# Checking occupancy at position 12 in row 0 to row 1
# [0. 0.]
# jeep 33: At the current speed, we are checking position 13 row 0 to 1
# jeep 33: At the current speed, we check until position 15
# Checking occupancy at position 13 in row 0 to row 1
# [0. 0.]
# jeep 33: At the current speed, we are checking position 14 row 0 to 1
# jeep 33: At the current speed, we check until position 15
# Checking occupancy at position 14 in row 0 to row 1
# [1. 1.]
# jeep 33 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 33 is at position 8
# AFTER MOVE DEBUGGER: jeep 33 is at position 11, with a speed of 3 at row 0
#  jeep 32 attributes
# ACCELERATE DEBUGGER: jeep 32 want to move at a speed of 4
# jeep 32's rear bumper is at 42
# jeep 32's front bumper is at 44
# jeep 32's maximum distance is  4
# jeep 32's road has length of 100
# jeep 32: default gap distance is 4
# jeep 32: At the current speed, we are checking position 45 row 0 to 1
# jeep 32: At the current speed, we check until position 48
# Checking occupancy at position 45 in row 0 to row 1
# [0. 0.]
# jeep 32: At the current speed, we are checking position 46 row 0 to 1
# jeep 32: At the current speed, we check until position 48
# Checking occupancy at position 46 in row 0 to row 1
# [0. 0.]
# jeep 32: At the current speed, we are checking position 47 row 0 to 1
# jeep 32: At the current speed, we check until position 48
# Checking occupancy at position 47 in row 0 to row 1
# [0. 0.]
# jeep 32: At the current speed, we are checking position 48 row 0 to 1
# jeep 32: At the current speed, we check until position 48
# Checking occupancy wrap-around at position 48 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 32 is at position 42
# AFTER MOVE DEBUGGER: jeep 32 is at position 46, with a speed of 4 at row 0
#  truck 20 attributes
# ACCELERATE DEBUGGER: truck 20 want to move at a speed of 3
# truck 20's rear bumper is at 77
# truck 20's front bumper is at 83
# truck 20's maximum distance is  3
# truck 20's road has length of 100
# truck 20: default gap distance is 3
# truck 20: At the current speed, we are checking position 84 row 2 to 3
# truck 20: At the current speed, we check until position 86
# Checking occupancy at position 84 in row 2 to row 3
# [2. 2.]
# truck20 has a gap distance of 0
# truck 20's rear bumper is at 77
# truck 20's front bumper is at 83
# truck 20's maximum distance is  3
# truck 20's road has length of 100
# truck 20: default gap distance is 3
# truck 20: At the current speed, we are checking position 84 row 2 to 3
# truck 20: At the current speed, we check until position 86
# Checking occupancy at position 84 in row 1 to row 2
# [1. 2.]
#  The right row(and its corresponding lane) of truck 20 has an available space of 0 cells.
#  The left row(and its corresponding lane) of truck 20 has an available space of 0 cells.
# truck 20's rear bumper is at 77
# truck 20's front bumper is at 83
# truck 20's maximum distance is  3
# truck 20's road has length of 100
# truck 20: default gap distance is 3
# truck 20: At the current speed, we are checking position 84 row 2 to 3
# truck 20: At the current speed, we check until position 86
# Checking occupancy at position 84 in row 2 to row 3
# [2. 2.]
# truck 20 is decelerating on own lane
# BEFORE MOVE DEBUGGER: truck 20 is at position 77
# AFTER MOVE DEBUGGER: truck 20 is at position 77, with a speed of 0 at row 2
#  jeep 40 attributes
# ACCELERATE DEBUGGER: jeep 40 want to move at a speed of 3
# jeep 40's rear bumper is at 99
# jeep 40's front bumper is at 101
# jeep 40's maximum distance is  3
# jeep 40's road has length of 100
# jeep 40: default gap distance is 3
# jeep 40: At the current speed, we are checking position 2 row 0 to 1
# jeep 40: At the current speed, we check until position 4
# Checking occupancy at position 2 in row 0 to row 1
# [1. 1.]
# jeep 40 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 40 is at position 99
# AFTER MOVE DEBUGGER: jeep 40 is at position 99, with a speed of 0 at row 0
#  jeep 28 attributes
# ACCELERATE DEBUGGER: jeep 28 want to move at a speed of 3
# jeep 28's rear bumper is at 85
# jeep 28's front bumper is at 87
# jeep 28's maximum distance is  3
# jeep 28's road has length of 100
# jeep 28: default gap distance is 3
# jeep 28: At the current speed, we are checking position 88 row 0 to 1
# jeep 28: At the current speed, we check until position 90
# Checking occupancy at position 88 in row 0 to row 1
# [0. 0.]
# jeep 28: At the current speed, we are checking position 89 row 0 to 1
# jeep 28: At the current speed, we check until position 90
# Checking occupancy at position 89 in row 0 to row 1
# [1. 1.]
# jeep 28 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 28 is at position 85
# AFTER MOVE DEBUGGER: jeep 28 is at position 86, with a speed of 1 at row 0
#  jeep 24 attributes
# ACCELERATE DEBUGGER: jeep 24 want to move at a speed of 5
# jeep 24's rear bumper is at 1
# jeep 24's front bumper is at 3
# jeep 24's maximum distance is  5
# jeep 24's road has length of 100
# jeep 24: default gap distance is 5
# jeep 24: At the current speed, we are checking position 4 row 0 to 1
# jeep 24: At the current speed, we check until position 8
# Checking occupancy at position 4 in row 0 to row 1
# [1. 1.]
# jeep 24 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 24 is at position 1
# AFTER MOVE DEBUGGER: jeep 24 is at position 1, with a speed of 0 at row 0
#  jeep 37 attributes
# ACCELERATE DEBUGGER: jeep 37 want to move at a speed of 3
# jeep 37's rear bumper is at 82
# jeep 37's front bumper is at 84
# jeep 37's maximum distance is  3
# jeep 37's road has length of 100
# jeep 37: default gap distance is 3
# jeep 37: At the current speed, we are checking position 85 row 0 to 1
# jeep 37: At the current speed, we check until position 87
# Checking occupancy at position 85 in row 0 to row 1
# [1. 1.]
# jeep 37 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 37 is at position 82
# AFTER MOVE DEBUGGER: jeep 37 is at position 82, with a speed of 0 at row 0
#  jeep 31 attributes
# ACCELERATE DEBUGGER: jeep 31 want to move at a speed of 4
# jeep 31's rear bumper is at 51
# jeep 31's front bumper is at 53
# jeep 31's maximum distance is  4
# jeep 31's road has length of 100
# jeep 31: default gap distance is 4
# jeep 31: At the current speed, we are checking position 54 row 0 to 1
# jeep 31: At the current speed, we check until position 57
# Checking occupancy at position 54 in row 0 to row 1
# [0. 0.]
# jeep 31: At the current speed, we are checking position 55 row 0 to 1
# jeep 31: At the current speed, we check until position 57
# Checking occupancy at position 55 in row 0 to row 1
# [1. 1.]
# jeep 31 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 31 is at position 51
# AFTER MOVE DEBUGGER: jeep 31 is at position 52, with a speed of 1 at row 0
#  jeep 27 attributes
# ACCELERATE DEBUGGER: jeep 27 want to move at a speed of 3
# jeep 27's rear bumper is at 32
# jeep 27's front bumper is at 34
# jeep 27's maximum distance is  3
# jeep 27's road has length of 100
# jeep 27: default gap distance is 3
# jeep 27: At the current speed, we are checking position 35 row 0 to 1
# jeep 27: At the current speed, we check until position 37
# Checking occupancy at position 35 in row 0 to row 1
# [0. 0.]
# jeep 27: At the current speed, we are checking position 36 row 0 to 1
# jeep 27: At the current speed, we check until position 37
# Checking occupancy at position 36 in row 0 to row 1
# [0. 0.]
# jeep 27: At the current speed, we are checking position 37 row 0 to 1
# jeep 27: At the current speed, we check until position 37
# Checking occupancy wrap-around at position 37 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 27 is at position 32
# AFTER MOVE DEBUGGER: jeep 27 is at position 35, with a speed of 3 at row 0
#  jeep 36 attributes
# ACCELERATE DEBUGGER: jeep 36 want to move at a speed of 4
# jeep 36's rear bumper is at 55
# jeep 36's front bumper is at 57
# jeep 36's maximum distance is  4
# jeep 36's road has length of 100
# jeep 36: default gap distance is 4
# jeep 36: At the current speed, we are checking position 58 row 0 to 1
# jeep 36: At the current speed, we check until position 61
# Checking occupancy at position 58 in row 0 to row 1
# [0. 0.]
# jeep 36: At the current speed, we are checking position 59 row 0 to 1
# jeep 36: At the current speed, we check until position 61
# Checking occupancy at position 59 in row 0 to row 1
# [0. 0.]
# jeep 36: At the current speed, we are checking position 60 row 0 to 1
# jeep 36: At the current speed, we check until position 61
# Checking occupancy at position 60 in row 0 to row 1
# [0. 0.]
# jeep 36: At the current speed, we are checking position 61 row 0 to 1
# jeep 36: At the current speed, we check until position 61
# Checking occupancy wrap-around at position 61 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 36 is at position 55
# AFTER MOVE DEBUGGER: jeep 36 is at position 59, with a speed of 4 at row 0
#  jeep 32 attributes
# ACCELERATE DEBUGGER: jeep 32 want to move at a speed of 5
# jeep 32's rear bumper is at 46
# jeep 32's front bumper is at 48
# jeep 32's maximum distance is  5
# jeep 32's road has length of 100
# jeep 32: default gap distance is 5
# jeep 32: At the current speed, we are checking position 49 row 0 to 1
# jeep 32: At the current speed, we check until position 53
# Checking occupancy at position 49 in row 0 to row 1
# [0. 0.]
# jeep 32: At the current speed, we are checking position 50 row 0 to 1
# jeep 32: At the current speed, we check until position 53
# Checking occupancy at position 50 in row 0 to row 1
# [0. 0.]
# jeep 32: At the current speed, we are checking position 51 row 0 to 1
# jeep 32: At the current speed, we check until position 53
# Checking occupancy at position 51 in row 0 to row 1
# [0. 0.]
# jeep 32: At the current speed, we are checking position 52 row 0 to 1
# jeep 32: At the current speed, we check until position 53
# Checking occupancy at position 52 in row 0 to row 1
# [1. 1.]
# jeep 32 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 32 is at position 46
# AFTER MOVE DEBUGGER: jeep 32 is at position 49, with a speed of 3 at row 0
#  truck 21 attributes
# ACCELERATE DEBUGGER: truck 21 want to move at a speed of 5
# truck 21's rear bumper is at 17
# truck 21's front bumper is at 23
# truck 21's maximum distance is  5
# truck 21's road has length of 100
# truck 21: default gap distance is 5
# truck 21: At the current speed, we are checking position 24 row 2 to 3
# truck 21: At the current speed, we check until position 28
# Checking occupancy at position 24 in row 2 to row 3
# [0. 0.]
# truck 21: At the current speed, we are checking position 25 row 2 to 3
# truck 21: At the current speed, we check until position 28
# Checking occupancy at position 25 in row 2 to row 3
# [0. 0.]
# truck 21: At the current speed, we are checking position 26 row 2 to 3
# truck 21: At the current speed, we check until position 28
# Checking occupancy at position 26 in row 2 to row 3
# [0. 0.]
# truck 21: At the current speed, we are checking position 27 row 2 to 3
# truck 21: At the current speed, we check until position 28
# Checking occupancy at position 27 in row 2 to row 3
# [0. 0.]
# truck 21: At the current speed, we are checking position 28 row 2 to 3
# truck 21: At the current speed, we check until position 28
# Checking occupancy wrap-around at position 28 in row 2 to row 3
# [0. 0.]
# BEFORE MOVE DEBUGGER: truck 21 is at position 17
# AFTER MOVE DEBUGGER: truck 21 is at position 22, with a speed of 5 at row 2
#  jeep 34 attributes
# ACCELERATE DEBUGGER: jeep 34 want to move at a speed of 2
# jeep 34's rear bumper is at 96
# jeep 34's front bumper is at 98
# jeep 34's maximum distance is  2
# jeep 34's road has length of 100
# jeep 34: default gap distance is 2
# jeep 34: At the current speed, we are checking position 99 row 0 to 1
# jeep 34: At the current speed, we check until position 0
# Checking occupancy wrap-around at position 99 in row 0 to row 1
# [1. 1.]
# jeep 34 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 34 is at position 96
# AFTER MOVE DEBUGGER: jeep 34 is at position 96, with a speed of 0 at row 0
#  jeep 36 attributes
# ACCELERATE DEBUGGER: jeep 36 want to move at a speed of 5
# jeep 36's rear bumper is at 59
# jeep 36's front bumper is at 61
# jeep 36's maximum distance is  5
# jeep 36's road has length of 100
# jeep 36: default gap distance is 5
# jeep 36: At the current speed, we are checking position 62 row 0 to 1
# jeep 36: At the current speed, we check until position 66
# Checking occupancy at position 62 in row 0 to row 1
# [0. 0.]
# jeep 36: At the current speed, we are checking position 63 row 0 to 1
# jeep 36: At the current speed, we check until position 66
# Checking occupancy at position 63 in row 0 to row 1
# [0. 0.]
# jeep 36: At the current speed, we are checking position 64 row 0 to 1
# jeep 36: At the current speed, we check until position 66
# Checking occupancy at position 64 in row 0 to row 1
# [1. 1.]
# jeep 36 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 36 is at position 59
# AFTER MOVE DEBUGGER: jeep 36 is at position 61, with a speed of 2 at row 0
#  jeep 31 attributes
# ACCELERATE DEBUGGER: jeep 31 want to move at a speed of 2
# jeep 31's rear bumper is at 52
# jeep 31's front bumper is at 54
# jeep 31's maximum distance is  2
# jeep 31's road has length of 100
# jeep 31: default gap distance is 2
# jeep 31: At the current speed, we are checking position 55 row 0 to 1
# jeep 31: At the current speed, we check until position 56
# Checking occupancy at position 55 in row 0 to row 1
# [0. 0.]
# jeep 31: At the current speed, we are checking position 56 row 0 to 1
# jeep 31: At the current speed, we check until position 56
# Checking occupancy wrap-around at position 56 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 31 is at position 52
# AFTER MOVE DEBUGGER: jeep 31 is at position 54, with a speed of 2 at row 0
#  truck 22 attributes
# ACCELERATE DEBUGGER: truck 22 want to move at a speed of 1
# truck 22's rear bumper is at 34
# truck 22's front bumper is at 40
# truck 22's maximum distance is  1
# truck 22's road has length of 100
# truck 22: default gap distance is 1
# truck 22: At the current speed, we are checking position 41 row 2 to 3
# truck 22: At the current speed, we check until position 41
# Checking occupancy wrap-around at position 41 in row 2 to row 3
# [0. 0.]
# BEFORE MOVE DEBUGGER: truck 22 is at position 34
# AFTER MOVE DEBUGGER: truck 22 is at position 35, with a speed of 1 at row 2
#  jeep 37 attributes
# ACCELERATE DEBUGGER: jeep 37 want to move at a speed of 1
# jeep 37's rear bumper is at 82
# jeep 37's front bumper is at 84
# jeep 37's maximum distance is  1
# jeep 37's road has length of 100
# jeep 37: default gap distance is 1
# jeep 37: At the current speed, we are checking position 85 row 0 to 1
# jeep 37: At the current speed, we check until position 85
# Checking occupancy wrap-around at position 85 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 37 is at position 82
# AFTER MOVE DEBUGGER: jeep 37 is at position 83, with a speed of 1 at row 0
#  jeep 26 attributes
# ACCELERATE DEBUGGER: jeep 26 want to move at a speed of 2
# jeep 26's rear bumper is at 5
# jeep 26's front bumper is at 7
# jeep 26's maximum distance is  2
# jeep 26's road has length of 100
# jeep 26: default gap distance is 2
# jeep 26: At the current speed, we are checking position 8 row 0 to 1
# jeep 26: At the current speed, we check until position 9
# Checking occupancy at position 8 in row 0 to row 1
# [0. 0.]
# jeep 26: At the current speed, we are checking position 9 row 0 to 1
# jeep 26: At the current speed, we check until position 9
# Checking occupancy wrap-around at position 9 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 26 is at position 5
# AFTER MOVE DEBUGGER: jeep 26 is at position 7, with a speed of 2 at row 0
#  jeep 33 attributes
# ACCELERATE DEBUGGER: jeep 33 want to move at a speed of 4
# jeep 33's rear bumper is at 11
# jeep 33's front bumper is at 13
# jeep 33's maximum distance is  4
# jeep 33's road has length of 100
# jeep 33: default gap distance is 4
# jeep 33: At the current speed, we are checking position 14 row 0 to 1
# jeep 33: At the current speed, we check until position 17
# Checking occupancy at position 14 in row 0 to row 1
# [0. 0.]
# jeep 33: At the current speed, we are checking position 15 row 0 to 1
# jeep 33: At the current speed, we check until position 17
# Checking occupancy at position 15 in row 0 to row 1
# [1. 1.]
# jeep 33 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 33 is at position 11
# AFTER MOVE DEBUGGER: jeep 33 is at position 12, with a speed of 1 at row 0
#  jeep 41 attributes
# ACCELERATE DEBUGGER: jeep 41 want to move at a speed of 3
# jeep 41's rear bumper is at 64
# jeep 41's front bumper is at 66
# jeep 41's maximum distance is  3
# jeep 41's road has length of 100
# jeep 41: default gap distance is 3
# jeep 41: At the current speed, we are checking position 67 row 0 to 1
# jeep 41: At the current speed, we check until position 69
# Checking occupancy at position 67 in row 0 to row 1
# [0. 0.]
# jeep 41: At the current speed, we are checking position 68 row 0 to 1
# jeep 41: At the current speed, we check until position 69
# Checking occupancy at position 68 in row 0 to row 1
# [0. 0.]
# jeep 41: At the current speed, we are checking position 69 row 0 to 1
# jeep 41: At the current speed, we check until position 69
# Checking occupancy wrap-around at position 69 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 41 is at position 64
# AFTER MOVE DEBUGGER: jeep 41 is at position 67, with a speed of 3 at row 0
#  jeep 30 attributes
# ACCELERATE DEBUGGER: jeep 30 want to move at a speed of 2
# jeep 30's rear bumper is at 39
# jeep 30's front bumper is at 41
# jeep 30's maximum distance is  2
# jeep 30's road has length of 100
# jeep 30: default gap distance is 2
# jeep 30: At the current speed, we are checking position 42 row 0 to 1
# jeep 30: At the current speed, we check until position 43
# Checking occupancy at position 42 in row 0 to row 1
# [0. 0.]
# jeep 30: At the current speed, we are checking position 43 row 0 to 1
# jeep 30: At the current speed, we check until position 43
# Checking occupancy wrap-around at position 43 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 30 is at position 39
# AFTER MOVE DEBUGGER: jeep 30 is at position 41, with a speed of 2 at row 0
#  jeep 29 attributes
# ACCELERATE DEBUGGER: jeep 29 want to move at a speed of 1
# jeep 29's rear bumper is at 18
# jeep 29's front bumper is at 20
# jeep 29's maximum distance is  1
# jeep 29's road has length of 100
# jeep 29: default gap distance is 1
# jeep 29: At the current speed, we are checking position 21 row 0 to 1
# jeep 29: At the current speed, we check until position 21
# Checking occupancy wrap-around at position 21 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 29 is at position 18
# AFTER MOVE DEBUGGER: jeep 29 is at position 19, with a speed of 1 at row 0
#  truck 20 attributes
# ACCELERATE DEBUGGER: truck 20 want to move at a speed of 1
# truck 20's rear bumper is at 77
# truck 20's front bumper is at 83
# truck 20's maximum distance is  1
# truck 20's road has length of 100
# truck 20: default gap distance is 1
# truck 20: At the current speed, we are checking position 84 row 2 to 3
# truck 20: At the current speed, we check until position 84
# Checking occupancy wrap-around at position 84 in row 2 to row 3
# [0. 0.]
# BEFORE MOVE DEBUGGER: truck 20 is at position 77
# AFTER MOVE DEBUGGER: truck 20 is at position 78, with a speed of 1 at row 2
#  jeep 40 attributes
# ACCELERATE DEBUGGER: jeep 40 want to move at a speed of 1
# jeep 40's rear bumper is at 99
# jeep 40's front bumper is at 101
# jeep 40's maximum distance is  1
# jeep 40's road has length of 100
# jeep 40: default gap distance is 1
# jeep 40: At the current speed, we are checking position 2 row 0 to 1
# jeep 40: At the current speed, we check until position 2
# Checking occupancy wrap-around at position 2 in row 0 to row 1
# [1. 1.]
# jeep 40 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 40 is at position 99
# AFTER MOVE DEBUGGER: jeep 40 is at position 99, with a speed of 0 at row 0
#  jeep 23 attributes
# ACCELERATE DEBUGGER: jeep 23 want to move at a speed of 4
# jeep 23's rear bumper is at 92
# jeep 23's front bumper is at 94
# jeep 23's maximum distance is  4
# jeep 23's road has length of 100
# jeep 23: default gap distance is 4
# jeep 23: At the current speed, we are checking position 95 row 0 to 1
# jeep 23: At the current speed, we check until position 98
# Checking occupancy at position 95 in row 0 to row 1
# [0. 0.]
# jeep 23: At the current speed, we are checking position 96 row 0 to 1
# jeep 23: At the current speed, we check until position 98
# Checking occupancy at position 96 in row 0 to row 1
# [1. 1.]
# jeep 23 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 23 is at position 92
# AFTER MOVE DEBUGGER: jeep 23 is at position 93, with a speed of 1 at row 0
#  jeep 24 attributes
# ACCELERATE DEBUGGER: jeep 24 want to move at a speed of 1
# jeep 24's rear bumper is at 1
# jeep 24's front bumper is at 3
# jeep 24's maximum distance is  1
# jeep 24's road has length of 100
# jeep 24: default gap distance is 1
# jeep 24: At the current speed, we are checking position 4 row 0 to 1
# jeep 24: At the current speed, we check until position 4
# Checking occupancy wrap-around at position 4 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 24 is at position 1
# AFTER MOVE DEBUGGER: jeep 24 is at position 2, with a speed of 1 at row 0
#  jeep 28 attributes
# ACCELERATE DEBUGGER: jeep 28 want to move at a speed of 2
# jeep 28's rear bumper is at 86
# jeep 28's front bumper is at 88
# jeep 28's maximum distance is  2
# jeep 28's road has length of 100
# jeep 28: default gap distance is 2
# jeep 28: At the current speed, we are checking position 89 row 0 to 1
# jeep 28: At the current speed, we check until position 90
# Checking occupancy at position 89 in row 0 to row 1
# [0. 0.]
# jeep 28: At the current speed, we are checking position 90 row 0 to 1
# jeep 28: At the current speed, we check until position 90
# Checking occupancy wrap-around at position 90 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 28 is at position 86
# AFTER MOVE DEBUGGER: jeep 28 is at position 88, with a speed of 2 at row 0
#  truck 17 attributes
# ACCELERATE DEBUGGER: truck 17 want to move at a speed of 1
# truck 17's rear bumper is at 70
# truck 17's front bumper is at 76
# truck 17's maximum distance is  1
# truck 17's road has length of 100
# truck 17: default gap distance is 1
# truck 17: At the current speed, we are checking position 77 row 2 to 3
# truck 17: At the current speed, we check until position 77
# Checking occupancy wrap-around at position 77 in row 2 to row 3
# [2. 2.]
# truck 17 is decelerating on own lane
# BEFORE MOVE DEBUGGER: truck 17 is at position 70
# AFTER MOVE DEBUGGER: truck 17 is at position 70, with a speed of 0 at row 2
#  jeep 38 attributes
# ACCELERATE DEBUGGER: jeep 38 want to move at a speed of 2
# jeep 38's rear bumper is at 15
# jeep 38's front bumper is at 17
# jeep 38's maximum distance is  2
# jeep 38's road has length of 100
# jeep 38: default gap distance is 2
# jeep 38: At the current speed, we are checking position 18 row 0 to 1
# jeep 38: At the current speed, we check until position 19
# Checking occupancy at position 18 in row 0 to row 1
# [1. 1.]
# jeep 38 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 38 is at position 15
# AFTER MOVE DEBUGGER: jeep 38 is at position 15, with a speed of 0 at row 0
#  truck 19 attributes
# ACCELERATE DEBUGGER: truck 19 want to move at a speed of 4
# truck 19's rear bumper is at 87
# truck 19's front bumper is at 93
# truck 19's maximum distance is  4
# truck 19's road has length of 100
# truck 19: default gap distance is 4
# truck 19: At the current speed, we are checking position 94 row 2 to 3
# truck 19: At the current speed, we check until position 97
# Checking occupancy at position 94 in row 2 to row 3
# [0. 0.]
# truck 19: At the current speed, we are checking position 95 row 2 to 3
# truck 19: At the current speed, we check until position 97
# Checking occupancy at position 95 in row 2 to row 3
# [0. 0.]
# truck 19: At the current speed, we are checking position 96 row 2 to 3
# truck 19: At the current speed, we check until position 97
# Checking occupancy at position 96 in row 2 to row 3
# [0. 0.]
# truck 19: At the current speed, we are checking position 97 row 2 to 3
# truck 19: At the current speed, we check until position 97
# Checking occupancy wrap-around at position 97 in row 2 to row 3
# [0. 0.]
# BEFORE MOVE DEBUGGER: truck 19 is at position 87
# AFTER MOVE DEBUGGER: truck 19 is at position 91, with a speed of 4 at row 2
#  truck 18 attributes
# ACCELERATE DEBUGGER: truck 18 want to move at a speed of 5
# truck 18's rear bumper is at 45
# truck 18's front bumper is at 51
# truck 18's maximum distance is  5
# truck 18's road has length of 100
# truck 18: default gap distance is 5
# truck 18: At the current speed, we are checking position 52 row 2 to 3
# truck 18: At the current speed, we check until position 56
# Checking occupancy at position 52 in row 2 to row 3
# [0. 0.]
# truck 18: At the current speed, we are checking position 53 row 2 to 3
# truck 18: At the current speed, we check until position 56
# Checking occupancy at position 53 in row 2 to row 3
# [0. 0.]
# truck 18: At the current speed, we are checking position 54 row 2 to 3
# truck 18: At the current speed, we check until position 56
# Checking occupancy at position 54 in row 2 to row 3
# [0. 0.]
# truck 18: At the current speed, we are checking position 55 row 2 to 3
# truck 18: At the current speed, we check until position 56
# Checking occupancy at position 55 in row 2 to row 3
# [0. 0.]
# truck 18: At the current speed, we are checking position 56 row 2 to 3
# truck 18: At the current speed, we check until position 56
# Checking occupancy wrap-around at position 56 in row 2 to row 3
# [0. 0.]
# truck18 has a gap distance of 5
# truck 18's rear bumper is at 45
# truck 18's front bumper is at 51
# truck 18's maximum distance is  5
# truck 18's road has length of 100
# truck 18: default gap distance is 5
# truck 18: At the current speed, we are checking position 52 row 2 to 3
# truck 18: At the current speed, we check until position 56
# Checking occupancy at position 52 in row 1 to row 2
# [1. 0.]
#  The right row(and its corresponding lane) of truck 18 has an available space of 0 cells.
#  The left row(and its corresponding lane) of truck 18 has an available space of 5 cells.
# truck 18's rear bumper is at 45
# truck 18's front bumper is at 51
# truck 18's maximum distance is  5
# truck 18's road has length of 100
# truck 18: default gap distance is 5
# truck 18: At the current speed, we are checking position 52 row 2 to 3
# truck 18: At the current speed, we check until position 56
# Checking occupancy at position 52 in row 2 to row 3
# [0. 0.]
# truck 18: At the current speed, we are checking position 53 row 2 to 3
# truck 18: At the current speed, we check until position 56
# Checking occupancy at position 53 in row 2 to row 3
# [0. 0.]
# truck 18: At the current speed, we are checking position 54 row 2 to 3
# truck 18: At the current speed, we check until position 56
# Checking occupancy at position 54 in row 2 to row 3
# [0. 0.]
# truck 18: At the current speed, we are checking position 55 row 2 to 3
# truck 18: At the current speed, we check until position 56
# Checking occupancy at position 55 in row 2 to row 3
# [0. 0.]
# truck 18: At the current speed, we are checking position 56 row 2 to 3
# truck 18: At the current speed, we check until position 56
# Checking occupancy wrap-around at position 56 in row 2 to row 3
# [0. 0.]
# BEFORE MOVE DEBUGGER: truck 18 is at position 45
# AFTER MOVE DEBUGGER: truck 18 is at position 50, with a speed of 5 at row 2
#  jeep 25 attributes
# ACCELERATE DEBUGGER: jeep 25 want to move at a speed of 5
# jeep 25's rear bumper is at 25
# jeep 25's front bumper is at 27
# jeep 25's maximum distance is  5
# jeep 25's road has length of 100
# jeep 25: default gap distance is 5
# jeep 25: At the current speed, we are checking position 28 row 0 to 1
# jeep 25: At the current speed, we check until position 32
# Checking occupancy at position 28 in row 0 to row 1
# [0. 0.]
# jeep 25: At the current speed, we are checking position 29 row 0 to 1
# jeep 25: At the current speed, we check until position 32
# Checking occupancy at position 29 in row 0 to row 1
# [1. 1.]
# jeep 25 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 25 is at position 25
# AFTER MOVE DEBUGGER: jeep 25 is at position 26, with a speed of 1 at row 0
#  jeep 35 attributes
# ACCELERATE DEBUGGER: jeep 35 want to move at a speed of 5
# jeep 35's rear bumper is at 79
# jeep 35's front bumper is at 81
# jeep 35's maximum distance is  5
# jeep 35's road has length of 100
# jeep 35: default gap distance is 5
# jeep 35: At the current speed, we are checking position 82 row 0 to 1
# jeep 35: At the current speed, we check until position 86
# Checking occupancy at position 82 in row 0 to row 1
# [1. 1.]
# jeep 35 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 35 is at position 79
# AFTER MOVE DEBUGGER: jeep 35 is at position 79, with a speed of 0 at row 0
#  jeep 27 attributes
# ACCELERATE DEBUGGER: jeep 27 want to move at a speed of 4
# jeep 27's rear bumper is at 35
# jeep 27's front bumper is at 37
# jeep 27's maximum distance is  4
# jeep 27's road has length of 100
# jeep 27: default gap distance is 4
# jeep 27: At the current speed, we are checking position 38 row 0 to 1
# jeep 27: At the current speed, we check until position 41
# Checking occupancy at position 38 in row 0 to row 1
# [0. 0.]
# jeep 27: At the current speed, we are checking position 39 row 0 to 1
# jeep 27: At the current speed, we check until position 41
# Checking occupancy at position 39 in row 0 to row 1
# [1. 1.]
# jeep 27 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 27 is at position 35
# AFTER MOVE DEBUGGER: jeep 27 is at position 36, with a speed of 1 at row 0
#  jeep 39 attributes
# ACCELERATE DEBUGGER: jeep 39 want to move at a speed of 2
# jeep 39's rear bumper is at 29
# jeep 39's front bumper is at 31
# jeep 39's maximum distance is  2
# jeep 39's road has length of 100
# jeep 39: default gap distance is 2
# jeep 39: At the current speed, we are checking position 32 row 0 to 1
# jeep 39: At the current speed, we check until position 33
# Checking occupancy at position 32 in row 0 to row 1
# [0. 0.]
# jeep 39: At the current speed, we are checking position 33 row 0 to 1
# jeep 39: At the current speed, we check until position 33
# Checking occupancy wrap-around at position 33 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 39 is at position 29
# AFTER MOVE DEBUGGER: jeep 39 is at position 31, with a speed of 2 at row 0
#  jeep 27 attributes
# ACCELERATE DEBUGGER: jeep 27 want to move at a speed of 2
# jeep 27's rear bumper is at 36
# jeep 27's front bumper is at 38
# jeep 27's maximum distance is  2
# jeep 27's road has length of 100
# jeep 27: default gap distance is 2
# jeep 27: At the current speed, we are checking position 39 row 0 to 1
# jeep 27: At the current speed, we check until position 40
# Checking occupancy at position 39 in row 0 to row 1
# [0. 0.]
# jeep 27: At the current speed, we are checking position 40 row 0 to 1
# jeep 27: At the current speed, we check until position 40
# Checking occupancy wrap-around at position 40 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 27 is at position 36
# AFTER MOVE DEBUGGER: jeep 27 is at position 38, with a speed of 2 at row 0
#  truck 21 attributes
# ACCELERATE DEBUGGER: truck 21 want to move at a speed of 5
# truck 21's rear bumper is at 22
# truck 21's front bumper is at 28
# truck 21's maximum distance is  5
# truck 21's road has length of 100
# truck 21: default gap distance is 5
# truck 21: At the current speed, we are checking position 29 row 2 to 3
# truck 21: At the current speed, we check until position 33
# Checking occupancy at position 29 in row 2 to row 3
# [0. 0.]
# truck 21: At the current speed, we are checking position 30 row 2 to 3
# truck 21: At the current speed, we check until position 33
# Checking occupancy at position 30 in row 2 to row 3
# [0. 0.]
# truck 21: At the current speed, we are checking position 31 row 2 to 3
# truck 21: At the current speed, we check until position 33
# Checking occupancy at position 31 in row 2 to row 3
# [0. 0.]
# ...
# [0. 0.]
# truck 22: At the current speed, we are checking position 70 row 2 to 3
# truck 22: At the current speed, we check until position 72
# Checking occupancy at position 70 in row 2 to row 3
# [0. 0.]
# truck 22: At the current speed, we are checking position 71 row 2 to 3
# truck 22: At the current speed, we check until position 72
# Checking occupancy at position 71 in row 2 to row 3
# [0. 0.]
# truck 22: At the current speed, we are checking position 72 row 2 to 3
# truck 22: At the current speed, we check until position 72
# Checking occupancy wrap-around at position 72 in row 2 to row 3
# [0. 0.]
# BEFORE MOVE DEBUGGER: truck 22 is at position 61
# AFTER MOVE DEBUGGER: truck 22 is at position 66, with a speed of 5 at row 2
#  jeep 26 attributes
# ACCELERATE DEBUGGER: jeep 26 want to move at a speed of 3
# jeep 26's rear bumper is at 20
# jeep 26's front bumper is at 22
# jeep 26's maximum distance is  3
# jeep 26's road has length of 100
# jeep 26: default gap distance is 3
# jeep 26: At the current speed, we are checking position 23 row 0 to 1
# jeep 26: At the current speed, we check until position 25
# Checking occupancy at position 23 in row 0 to row 1
# [0. 0.]
# jeep 26: At the current speed, we are checking position 24 row 0 to 1
# jeep 26: At the current speed, we check until position 25
# Checking occupancy at position 24 in row 0 to row 1
# [0. 0.]
# jeep 26: At the current speed, we are checking position 25 row 0 to 1
# jeep 26: At the current speed, we check until position 25
# Checking occupancy wrap-around at position 25 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 26 is at position 20
# AFTER MOVE DEBUGGER: jeep 26 is at position 23, with a speed of 3 at row 0
#  truck 20 attributes
# ACCELERATE DEBUGGER: truck 20 want to move at a speed of 5
# truck 20's rear bumper is at 7
# truck 20's front bumper is at 13
# truck 20's maximum distance is  5
# truck 20's road has length of 100
# truck 20: default gap distance is 5
# truck 20: At the current speed, we are checking position 14 row 2 to 3
# truck 20: At the current speed, we check until position 18
# Checking occupancy at position 14 in row 2 to row 3
# [0. 0.]
# truck 20: At the current speed, we are checking position 15 row 2 to 3
# truck 20: At the current speed, we check until position 18
# Checking occupancy at position 15 in row 2 to row 3
# [0. 0.]
# truck 20: At the current speed, we are checking position 16 row 2 to 3
# truck 20: At the current speed, we check until position 18
# Checking occupancy at position 16 in row 2 to row 3
# [0. 0.]
# truck 20: At the current speed, we are checking position 17 row 2 to 3
# truck 20: At the current speed, we check until position 18
# Checking occupancy at position 17 in row 2 to row 3
# [0. 0.]
# truck 20: At the current speed, we are checking position 18 row 2 to 3
# truck 20: At the current speed, we check until position 18
# Checking occupancy wrap-around at position 18 in row 2 to row 3
# [0. 0.]
# BEFORE MOVE DEBUGGER: truck 20 is at position 7
# AFTER MOVE DEBUGGER: truck 20 is at position 12, with a speed of 5 at row 2
#  jeep 34 attributes
# ACCELERATE DEBUGGER: jeep 34 want to move at a speed of 3
# jeep 34's rear bumper is at 3
# jeep 34's front bumper is at 5
# jeep 34's maximum distance is  3
# jeep 34's road has length of 100
# jeep 34: default gap distance is 3
# jeep 34: At the current speed, we are checking position 6 row 0 to 1
# jeep 34: At the current speed, we check until position 8
# Checking occupancy at position 6 in row 0 to row 1
# [0. 0.]
# jeep 34: At the current speed, we are checking position 7 row 0 to 1
# jeep 34: At the current speed, we check until position 8
# Checking occupancy at position 7 in row 0 to row 1
# [0. 0.]
# jeep 34: At the current speed, we are checking position 8 row 0 to 1
# jeep 34: At the current speed, we check until position 8
# Checking occupancy wrap-around at position 8 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 34 is at position 3
# AFTER MOVE DEBUGGER: jeep 34 is at position 6, with a speed of 3 at row 0
#  jeep 31 attributes
# ACCELERATE DEBUGGER: jeep 31 want to move at a speed of 1
# jeep 31's rear bumper is at 75
# jeep 31's front bumper is at 77
# jeep 31's maximum distance is  1
# jeep 31's road has length of 100
# jeep 31: default gap distance is 1
# jeep 31: At the current speed, we are checking position 78 row 0 to 1
# jeep 31: At the current speed, we check until position 78
# Checking occupancy wrap-around at position 78 in row 0 to row 1
# [1. 1.]
# jeep 31 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 31 is at position 75
# AFTER MOVE DEBUGGER: jeep 31 is at position 75, with a speed of 0 at row 0
#  truck 17 attributes
# ACCELERATE DEBUGGER: truck 17 want to move at a speed of 5
# truck 17's rear bumper is at 95
# truck 17's front bumper is at 101
# truck 17's maximum distance is  5
# truck 17's road has length of 100
# truck 17: default gap distance is 5
# truck 17: At the current speed, we are checking position 2 row 2 to 3
# truck 17: At the current speed, we check until position 6
# Checking occupancy at position 2 in row 2 to row 3
# [0. 0.]
# truck 17: At the current speed, we are checking position 3 row 2 to 3
# truck 17: At the current speed, we check until position 6
# Checking occupancy at position 3 in row 2 to row 3
# [0. 0.]
# truck 17: At the current speed, we are checking position 4 row 2 to 3
# truck 17: At the current speed, we check until position 6
# Checking occupancy at position 4 in row 2 to row 3
# [0. 0.]
# truck 17: At the current speed, we are checking position 5 row 2 to 3
# truck 17: At the current speed, we check until position 6
# Checking occupancy at position 5 in row 2 to row 3
# [0. 0.]
# truck 17: At the current speed, we are checking position 6 row 2 to 3
# truck 17: At the current speed, we check until position 6
# Checking occupancy wrap-around at position 6 in row 2 to row 3
# [0. 0.]
# truck17 has a gap distance of 5
# truck 17's rear bumper is at 95
# truck 17's front bumper is at 101
# truck 17's maximum distance is  5
# truck 17's road has length of 100
# truck 17: default gap distance is 5
# truck 17: At the current speed, we are checking position 2 row 2 to 3
# truck 17: At the current speed, we check until position 6
# Checking occupancy at position 2 in row 1 to row 2
# [0. 0.]
# truck 17: At the current speed, we are checking position 3 row 2 to 3
# truck 17: At the current speed, we check until position 6
# Checking occupancy at position 3 in row 1 to row 2
# [1. 0.]
#  The right row(and its corresponding lane) of truck 17 has an available space of 1 cells.
#  The left row(and its corresponding lane) of truck 17 has an available space of 5 cells.
# truck 17's rear bumper is at 95
# truck 17's front bumper is at 101
# truck 17's maximum distance is  5
# truck 17's road has length of 100
# truck 17: default gap distance is 5
# truck 17: At the current speed, we are checking position 2 row 2 to 3
# truck 17: At the current speed, we check until position 6
# Checking occupancy at position 2 in row 2 to row 3
# [0. 0.]
# truck 17: At the current speed, we are checking position 3 row 2 to 3
# truck 17: At the current speed, we check until position 6
# Checking occupancy at position 3 in row 2 to row 3
# [0. 0.]
# truck 17: At the current speed, we are checking position 4 row 2 to 3
# truck 17: At the current speed, we check until position 6
# Checking occupancy at position 4 in row 2 to row 3
# [0. 0.]
# truck 17: At the current speed, we are checking position 5 row 2 to 3
# truck 17: At the current speed, we check until position 6
# Checking occupancy at position 5 in row 2 to row 3
# [0. 0.]
# truck 17: At the current speed, we are checking position 6 row 2 to 3
# truck 17: At the current speed, we check until position 6
# Checking occupancy wrap-around at position 6 in row 2 to row 3
# [0. 0.]
# BEFORE MOVE DEBUGGER: truck 17 is at position 95
# AFTER MOVE DEBUGGER: truck 17 is at position 0, with a speed of 5 at row 2
#  jeep 23 attributes
# ACCELERATE DEBUGGER: jeep 23 want to move at a speed of 2
# jeep 23's rear bumper is at 98
# jeep 23's front bumper is at 100
# jeep 23's maximum distance is  2
# jeep 23's road has length of 100
# jeep 23: default gap distance is 2
# jeep 23: At the current speed, we are checking position 1 row 0 to 1
# jeep 23: At the current speed, we check until position 2
# Checking occupancy at position 1 in row 0 to row 1
# [0. 0.]
# jeep 23: At the current speed, we are checking position 2 row 0 to 1
# jeep 23: At the current speed, we check until position 2
# Checking occupancy wrap-around at position 2 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 23 is at position 98
# AFTER MOVE DEBUGGER: jeep 23 is at position 0, with a speed of 2 at row 0
#  jeep 24 attributes
# ACCELERATE DEBUGGER: jeep 24 want to move at a speed of 4
# jeep 24's rear bumper is at 15
# jeep 24's front bumper is at 17
# jeep 24's maximum distance is  4
# jeep 24's road has length of 100
# jeep 24: default gap distance is 4
# jeep 24: At the current speed, we are checking position 18 row 0 to 1
# jeep 24: At the current speed, we check until position 21
# Checking occupancy at position 18 in row 0 to row 1
# [0. 0.]
# jeep 24: At the current speed, we are checking position 19 row 0 to 1
# jeep 24: At the current speed, we check until position 21
# Checking occupancy at position 19 in row 0 to row 1
# [0. 0.]
# jeep 24: At the current speed, we are checking position 20 row 0 to 1
# jeep 24: At the current speed, we check until position 21
# Checking occupancy at position 20 in row 0 to row 1
# [1. 1.]
# jeep 24 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 24 is at position 15
# AFTER MOVE DEBUGGER: jeep 24 is at position 17, with a speed of 2 at row 0
#  jeep 27 attributes
# ACCELERATE DEBUGGER: jeep 27 want to move at a speed of 5
# jeep 27's rear bumper is at 61
# jeep 27's front bumper is at 63
# jeep 27's maximum distance is  5
# jeep 27's road has length of 100
# jeep 27: default gap distance is 5
# jeep 27: At the current speed, we are checking position 64 row 0 to 1
# jeep 27: At the current speed, we check until position 68
# Checking occupancy at position 64 in row 0 to row 1
# [0. 0.]
# jeep 27: At the current speed, we are checking position 65 row 0 to 1
# jeep 27: At the current speed, we check until position 68
# Checking occupancy at position 65 in row 0 to row 1
# [0. 0.]
# jeep 27: At the current speed, we are checking position 66 row 0 to 1
# jeep 27: At the current speed, we check until position 68
# Checking occupancy at position 66 in row 0 to row 1
# [0. 0.]
# jeep 27: At the current speed, we are checking position 67 row 0 to 1
# jeep 27: At the current speed, we check until position 68
# Checking occupancy at position 67 in row 0 to row 1
# [1. 1.]
# jeep 27 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 27 is at position 61
# AFTER MOVE DEBUGGER: jeep 27 is at position 64, with a speed of 3 at row 0
#  jeep 30 attributes
# ACCELERATE DEBUGGER: jeep 30 want to move at a speed of 4
# jeep 30's rear bumper is at 67
# jeep 30's front bumper is at 69
# jeep 30's maximum distance is  4
# jeep 30's road has length of 100
# jeep 30: default gap distance is 4
# jeep 30: At the current speed, we are checking position 70 row 0 to 1
# jeep 30: At the current speed, we check until position 73
# Checking occupancy at position 70 in row 0 to row 1
# [0. 0.]
# jeep 30: At the current speed, we are checking position 71 row 0 to 1
# jeep 30: At the current speed, we check until position 73
# Checking occupancy at position 71 in row 0 to row 1
# [0. 0.]
# jeep 30: At the current speed, we are checking position 72 row 0 to 1
# jeep 30: At the current speed, we check until position 73
# Checking occupancy at position 72 in row 0 to row 1
# [1. 1.]
# jeep 30 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 30 is at position 67
# AFTER MOVE DEBUGGER: jeep 30 is at position 69, with a speed of 2 at row 0
#  truck 18 attributes
# ACCELERATE DEBUGGER: truck 18 want to move at a speed of 5
# truck 18's rear bumper is at 83
# truck 18's front bumper is at 89
# truck 18's maximum distance is  5
# truck 18's road has length of 100
# truck 18: default gap distance is 5
# truck 18: At the current speed, we are checking position 90 row 2 to 3
# truck 18: At the current speed, we check until position 94
# Checking occupancy at position 90 in row 2 to row 3
# [0. 0.]
# truck 18: At the current speed, we are checking position 91 row 2 to 3
# truck 18: At the current speed, we check until position 94
# Checking occupancy at position 91 in row 2 to row 3
# [0. 0.]
# truck 18: At the current speed, we are checking position 92 row 2 to 3
# truck 18: At the current speed, we check until position 94
# Checking occupancy at position 92 in row 2 to row 3
# [0. 0.]
# truck 18: At the current speed, we are checking position 93 row 2 to 3
# truck 18: At the current speed, we check until position 94
# Checking occupancy at position 93 in row 2 to row 3
# [0. 0.]
# truck 18: At the current speed, we are checking position 94 row 2 to 3
# truck 18: At the current speed, we check until position 94
# Checking occupancy wrap-around at position 94 in row 2 to row 3
# [0. 0.]
# BEFORE MOVE DEBUGGER: truck 18 is at position 83
# AFTER MOVE DEBUGGER: truck 18 is at position 88, with a speed of 5 at row 2
#  jeep 39 attributes
# ACCELERATE DEBUGGER: jeep 39 want to move at a speed of 5
# jeep 39's rear bumper is at 53
# jeep 39's front bumper is at 55
# jeep 39's maximum distance is  5
# jeep 39's road has length of 100
# jeep 39: default gap distance is 5
# jeep 39: At the current speed, we are checking position 56 row 0 to 1
# jeep 39: At the current speed, we check until position 60
# Checking occupancy at position 56 in row 0 to row 1
# [0. 0.]
# jeep 39: At the current speed, we are checking position 57 row 0 to 1
# jeep 39: At the current speed, we check until position 60
# Checking occupancy at position 57 in row 0 to row 1
# [0. 0.]
# jeep 39: At the current speed, we are checking position 58 row 0 to 1
# jeep 39: At the current speed, we check until position 60
# Checking occupancy at position 58 in row 0 to row 1
# [0. 0.]
# jeep 39: At the current speed, we are checking position 59 row 0 to 1
# jeep 39: At the current speed, we check until position 60
# Checking occupancy at position 59 in row 0 to row 1
# [0. 0.]
# jeep 39: At the current speed, we are checking position 60 row 0 to 1
# jeep 39: At the current speed, we check until position 60
# Checking occupancy wrap-around at position 60 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 39 is at position 53
# AFTER MOVE DEBUGGER: jeep 39 is at position 58, with a speed of 5 at row 0
#  jeep 33 attributes
# ACCELERATE DEBUGGER: jeep 33 want to move at a speed of 4
# jeep 33's rear bumper is at 26
# jeep 33's front bumper is at 28
# jeep 33's maximum distance is  4
# jeep 33's road has length of 100
# jeep 33: default gap distance is 4
# jeep 33: At the current speed, we are checking position 29 row 0 to 1
# jeep 33: At the current speed, we check until position 32
# Checking occupancy at position 29 in row 0 to row 1
# [0. 0.]
# jeep 33: At the current speed, we are checking position 30 row 0 to 1
# jeep 33: At the current speed, we check until position 32
# Checking occupancy at position 30 in row 0 to row 1
# [0. 0.]
# jeep 33: At the current speed, we are checking position 31 row 0 to 1
# jeep 33: At the current speed, we check until position 32
# Checking occupancy at position 31 in row 0 to row 1
# [0. 0.]
# jeep 33: At the current speed, we are checking position 32 row 0 to 1
# jeep 33: At the current speed, we check until position 32
# Checking occupancy wrap-around at position 32 in row 0 to row 1
# [0. 0.]
# BEFORE MOVE DEBUGGER: jeep 33 is at position 26
# AFTER MOVE DEBUGGER: jeep 33 is at position 30, with a speed of 4 at row 0
#  jeep 32 attributes
# ACCELERATE DEBUGGER: jeep 32 want to move at a speed of 3
# jeep 32's rear bumper is at 72
# jeep 32's front bumper is at 74
# jeep 32's maximum distance is  3
# jeep 32's road has length of 100
# jeep 32: default gap distance is 3
# jeep 32: At the current speed, we are checking position 75 row 0 to 1
# jeep 32: At the current speed, we check until position 77
# Checking occupancy at position 75 in row 0 to row 1
# [1. 1.]
# jeep 32 is decelerating on own lane
# BEFORE MOVE DEBUGGER: jeep 32 is at position 72
# AFTER MOVE DEBUGGER: jeep 32 is at position 72, with a speed of 0 at row 0

# %% [markdown]
# MOVING CHECKER

# %%
def animate(step):
    simulator.simulation_step()  # Run a simulation step
    ax.clear()  # Clear the previous plot
    ax.imshow(simulator.road.road_occupancy.T, cmap='gray_r', origin='lower')
    ax.set_title(f'Step {step}')
    ax.set_xlabel('Road Length')
    ax.set_ylabel('Lane')
    ax.set_xticks(range(0, simulator.road.road_length + 1, 1))
    ax.set_yticks(range(0, simulator.road.road_width + 1, 1))
    ax.grid(True)

# Initialize road and simulator
road = Road(road_length=50, road_width=4, speed_limit=5)
simulator = IntraRoadSimulator(road)

density = 1
truck_fraction = 1

simulator.initialize_vehicles(density, truck_fraction, 1, 0)  # Initialize vehicles

# Set up the figure and axis for animation
fig, ax = plt.subplots(figsize=(20, 6))

# Create the animation
anim = FuncAnimation(fig, animate, frames=100, interval=300)

# Save the animation as a GIF or MP4
anim.save('road_simulation_vehicle_only(truck fraction = 1, density = 1).gif', writer='pillow')
# Or save as MP4
# anim.save('road_simulation.mp4', writer='ffmpeg')

# Show the animation in a Jupyter notebook (if using one)
plt.show()

# %%
# Define the density values you want to test
density_values = np.linspace(0, 1, 20)  # Example: 8 density points from 0.05 to 0.4
timesteps = 1000
truck_fraction = 0.3

# Create a directory to store the CSV files
output_dir = "density_timesteps_output2"
os.makedirs(output_dir, exist_ok=True)

for density in density_values:
    road = Road(road_length=200, road_width=4, speed_limit=5)
    simulator = IntraRoadSimulator(road)
    simulator.initialize_vehicles(density, truck_fraction, 1, 0)
    
    csv_filename = os.path.join(output_dir, f'density_{density:.2f}.csv')
    
    # Open the CSV file for writing
    with open(csv_filename, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["Timestep", "Throughput"])
        
        for step in range(timesteps):
            simulator.simulation_step(density, truck_fraction)
            throughput_at_step = simulator.vehicle_throughput
            writer.writerow([step + 1, throughput_at_step])
            
    print(f'Saved: {csv_filename}')

print("CSV files for all densities and timesteps have been saved.")
