# %%
from road import Road
from vehicle_sim import IntraRoadSimulator
from sidewalk import Sidewalk #Passenger
from passenger_sim import Passenger_Simulator
from main_sim import IntegratedSimulator

# %% [markdown]
# RUN SIMULATIONS IN ONE TRIAL

# %%
allowed_rows_input = [
    (0, {"truck" , "jeep"}), # Row 0 allowed for lane changing
    (1, {"truck" , "jeep"}),  
    (2, {"jeep", "truck"})  # Row 2 allowed for lane changing
]
jeepney_allowed_rows = [2] #allowed rows for initialization
truck_allowed_rows = [0, 2]  #allowed rows for initialization
safe_stopping_speed = 2
safe_deceleration = 2

# %%
# Create the sidewalk and road designations (for both pedestrian and vehicle simulators)
sidewalk = Sidewalk(length=50, width=1, max_passengers_per_cell=1)
road_designation = Road(length=50, width=4,speed_limit=5, allowed_rows =allowed_rows_input)
print(f"The allowed rows for each vehicle are {road_designation.allowed_rows}")
# Initialize the vehicle simulator (intra-road simulator) with required parameters
vehicle_simulator = IntraRoadSimulator(road=road_designation)

# Initialize the pedestrian simulator
pedestrian_simulator = Passenger_Simulator(
    sidewalk = sidewalk,
    passenger_arrival_rate = 1,  # Arrival rate of passengers per timestep
    road_designation=road_designation,
    max_passengers_per_cell = 5,
    vehicle_simulator = vehicle_simulator  # Pass the vehicle simulator to handle interactions
)

# Now, initialize the integrated simulator with both simulators
integrated_simulator = IntegratedSimulator(vehicle_simulator=vehicle_simulator, pedestrian_simulator=pedestrian_simulator)
# Out:
# The allowed rows for each vehicle are [(0, {'truck', 'jeep'}), (1, {'truck', 'jeep'}), (2, {'truck', 'jeep'})]

# %% [markdown]
# Run a Single Trial

# %%
integrated_simulator.run_simulation(200, 1, 1, 50, 0.4, 0, 1, safe_stopping_speed, safe_deceleration, jeepney_allowed_rows, truck_allowed_rows, visualize=True)
#max_timesteps, truck_lane_change_prob, jeep_lane_change_prob, transient_time, density, truck_fraction,stop_to_stop_distance, safe_stopping_speed, safe_deceleration, jeepney_allowed_rows, truck_allowed_rows,visualize=False
# Out:
# Vehicle 3's gap distance from the leading vehicle is 0
# Vehicle 3's gap distance from the leading vehicle is 1
# jeep 3 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 3's passenger destinations areset()
# jeep 3 calling attempt method.
# jeep 3 will try lane changing to the right lane
# jeep 3 has tried lane changing 0 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 3 checked a road portion with summed occupancy of 0.0
# Vehicle 3's gap distance from the leading vehicle is 0
# jeep 3 cannot straddle.
# jeep 3 has tried lane changing 1 times (incremented).
# jeep 3 attempted to load passengers. It attempted 1 times.
# jeep 3: Overshot a destination? --- False. Lane change trials  = 1
# jeep 3 has no passenger to be unloaded.
#  jeep 3 is inf cells away from the nearest destination.
#  jeep 3 is 0 cells away from the nearest pedestrian.
# Vehicle 3's gap distance from the leading vehicle is 0
#  jeep 3 is 0 cells away from the nearest vehicle.
#  jeep 3 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 3 needs to decelerate by 1
# jeep 3 has 0 before calling unloading method.
# jeep 3's passenger destinations areset()
# jeep 3: Unload Passengers? --- False
# jeep 3's passenger destinations areset()
# jeep 3 has 0 after calling unloading method.
# Vehicle 11's gap distance from the leading vehicle is 0
# Vehicle 11's gap distance from the leading vehicle is 1
# jeep 11 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 11's passenger destinations areset()
# jeep 11 calling attempt method.
# jeep 11 will try lane changing to the right lane
# jeep 11 has tried lane changing 0 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 11 checked a road portion with summed occupancy of 0.0
# Vehicle 11's gap distance from the leading vehicle is 0
# jeep 11 cannot straddle.
# jeep 11 has tried lane changing 1 times (incremented).
# jeep 11 attempted to load passengers. It attempted 1 times.
# jeep 11: Overshot a destination? --- False. Lane change trials  = 1
# jeep 11 has no passenger to be unloaded.
#  jeep 11 is inf cells away from the nearest destination.
#  jeep 11 is 0 cells away from the nearest pedestrian.
# Vehicle 11's gap distance from the leading vehicle is 0
#  jeep 11 is 0 cells away from the nearest vehicle.
#  jeep 11 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 11 needs to decelerate by 1
# jeep 11 has 0 before calling unloading method.
# jeep 11's passenger destinations areset()
# jeep 11: Unload Passengers? --- False
# jeep 11's passenger destinations areset()
# jeep 11 has 0 after calling unloading method.
# Vehicle 6's gap distance from the leading vehicle is 0
# Vehicle 6's gap distance from the leading vehicle is 1
# jeep 6 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 6's passenger destinations areset()
# jeep 6 calling attempt method.
# jeep 6 will try lane changing to the right lane
# jeep 6 has tried lane changing 0 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 6 checked a road portion with summed occupancy of 0.0
# Vehicle 6's gap distance from the leading vehicle is 0
# jeep 6 cannot straddle.
# jeep 6 has tried lane changing 1 times (incremented).
# jeep 6 attempted to load passengers. It attempted 1 times.
# jeep 6: Overshot a destination? --- False. Lane change trials  = 1
# jeep 6 has no passenger to be unloaded.
#  jeep 6 is inf cells away from the nearest destination.
#  jeep 6 is 0 cells away from the nearest pedestrian.
# Vehicle 6's gap distance from the leading vehicle is 0
#  jeep 6 is 0 cells away from the nearest vehicle.
#  jeep 6 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 6 needs to decelerate by 1
# jeep 6 has 0 before calling unloading method.
# jeep 6's passenger destinations areset()
# jeep 6: Unload Passengers? --- False
# jeep 6's passenger destinations areset()
# jeep 6 has 0 after calling unloading method.
# Vehicle 5's gap distance from the leading vehicle is 0
# Vehicle 5's gap distance from the leading vehicle is 1
# jeep 5 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 5's passenger destinations areset()
# jeep 5 calling attempt method.
# jeep 5 will try lane changing to the right lane
# jeep 5 has tried lane changing 0 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 5 checked a road portion with summed occupancy of 0.0
# Vehicle 5's gap distance from the leading vehicle is 0
# jeep 5 cannot straddle.
# jeep 5 has tried lane changing 1 times (incremented).
# jeep 5 attempted to load passengers. It attempted 1 times.
# jeep 5: Overshot a destination? --- False. Lane change trials  = 1
# jeep 5 has no passenger to be unloaded.
#  jeep 5 is inf cells away from the nearest destination.
#  jeep 5 is 0 cells away from the nearest pedestrian.
# Vehicle 5's gap distance from the leading vehicle is 0
#  jeep 5 is 0 cells away from the nearest vehicle.
#  jeep 5 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 5 needs to decelerate by 1
# jeep 5 has 0 before calling unloading method.
# jeep 5's passenger destinations areset()
# jeep 5: Unload Passengers? --- False
# jeep 5's passenger destinations areset()
# jeep 5 has 0 after calling unloading method.
# Vehicle 7's gap distance from the leading vehicle is 0
# Vehicle 7's gap distance from the leading vehicle is 1
# jeep 7 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 7's passenger destinations areset()
# jeep 7 calling attempt method.
# jeep 7 will try lane changing to the right lane
# jeep 7 has tried lane changing 0 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 7 checked a road portion with summed occupancy of 0.0
# Vehicle 7's gap distance from the leading vehicle is 0
# jeep 7 cannot straddle.
# jeep 7 has tried lane changing 1 times (incremented).
# jeep 7 attempted to load passengers. It attempted 1 times.
# jeep 7: Overshot a destination? --- False. Lane change trials  = 1
# jeep 7 has no passenger to be unloaded.
#  jeep 7 is inf cells away from the nearest destination.
#  jeep 7 is 0 cells away from the nearest pedestrian.
# Vehicle 7's gap distance from the leading vehicle is 0
#  jeep 7 is 0 cells away from the nearest vehicle.
#  jeep 7 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 7 needs to decelerate by 1
# jeep 7 has 0 before calling unloading method.
# jeep 7's passenger destinations areset()
# jeep 7: Unload Passengers? --- False
# jeep 7's passenger destinations areset()
# jeep 7 has 0 after calling unloading method.
# Vehicle 8's gap distance from the leading vehicle is 0
# Vehicle 8's gap distance from the leading vehicle is 1
# jeep 8 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 8's passenger destinations areset()
# jeep 8 calling attempt method.
# jeep 8 will try lane changing to the right lane
# jeep 8 has tried lane changing 0 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 8 checked a road portion with summed occupancy of 0.0
# Vehicle 8's gap distance from the leading vehicle is 0
# jeep 8 cannot straddle.
# jeep 8 has tried lane changing 1 times (incremented).
# jeep 8 attempted to load passengers. It attempted 1 times.
# jeep 8: Overshot a destination? --- False. Lane change trials  = 1
# jeep 8 has no passenger to be unloaded.
#  jeep 8 is inf cells away from the nearest destination.
#  jeep 8 is 0 cells away from the nearest pedestrian.
# Vehicle 8's gap distance from the leading vehicle is 0
#  jeep 8 is 0 cells away from the nearest vehicle.
#  jeep 8 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 8 needs to decelerate by 1
# jeep 8 has 0 before calling unloading method.
# jeep 8's passenger destinations areset()
# jeep 8: Unload Passengers? --- False
# jeep 8's passenger destinations areset()
# jeep 8 has 0 after calling unloading method.
# Vehicle 0's gap distance from the leading vehicle is 0
# Vehicle 0's gap distance from the leading vehicle is 1
# jeep 0 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 0's passenger destinations areset()
# jeep 0 calling attempt method.
# jeep 0 will try lane changing to the right lane
# jeep 0 has tried lane changing 0 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 0 checked a road portion with summed occupancy of 0.0
# Vehicle 0's gap distance from the leading vehicle is 0
# jeep 0 cannot straddle.
# jeep 0 has tried lane changing 1 times (incremented).
# jeep 0 attempted to load passengers. It attempted 1 times.
# jeep 0: Overshot a destination? --- False. Lane change trials  = 1
# jeep 0 has no passenger to be unloaded.
#  jeep 0 is inf cells away from the nearest destination.
#  jeep 0 is 0 cells away from the nearest pedestrian.
# Vehicle 0's gap distance from the leading vehicle is 0
#  jeep 0 is 0 cells away from the nearest vehicle.
#  jeep 0 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 0 needs to decelerate by 1
# jeep 0 has 0 before calling unloading method.
# jeep 0's passenger destinations areset()
# jeep 0: Unload Passengers? --- False
# jeep 0's passenger destinations areset()
# jeep 0 has 0 after calling unloading method.
# Vehicle 12's gap distance from the leading vehicle is 1
# Vehicle 12's gap distance from the leading vehicle is 1
# jeep 12 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 12's passenger destinations areset()
# jeep 12 calling attempt method.
# jeep 12 will try lane changing to the right lane
# jeep 12 has tried lane changing 0 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 12 checked a road portion with summed occupancy of 0.0
# Vehicle 12's gap distance from the leading vehicle is 1
# jeep 12 has tried lane changing 1 times (incremented).
# jeep 12 attempted to load passengers. It attempted 1 times.
# jeep 12: Overshot a destination? --- False. Lane change trials  = 1
# jeep 12 has no passenger to be unloaded.
#  jeep 12 is inf cells away from the nearest destination.
#  jeep 12 is 0 cells away from the nearest pedestrian.
# Vehicle 12's gap distance from the leading vehicle is 1
#  jeep 12 is 1 cells away from the nearest vehicle.
#  jeep 12 needs to decelerate by 1 to load passengers. Its current speed is 1 and target speed is 0
# jeep 12 needs to decelerate by 1
# jeep 12 has 0 before calling unloading method.
# jeep 12's passenger destinations areset()
# jeep 12: Unload Passengers? --- False
# jeep 12's passenger destinations areset()
# jeep 12 has 0 after calling unloading method.
# Vehicle 10's gap distance from the leading vehicle is 0
# Vehicle 10's gap distance from the leading vehicle is 1
# jeep 10 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 10's passenger destinations areset()
# jeep 10 calling attempt method.
# jeep 10 will try lane changing to the right lane
# jeep 10 has tried lane changing 0 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 10 checked a road portion with summed occupancy of 0.0
# Vehicle 10's gap distance from the leading vehicle is 0
# jeep 10 cannot straddle.
# jeep 10 has tried lane changing 1 times (incremented).
# jeep 10 attempted to load passengers. It attempted 1 times.
# jeep 10: Overshot a destination? --- False. Lane change trials  = 1
# jeep 10 has no passenger to be unloaded.
#  jeep 10 is inf cells away from the nearest destination.
#  jeep 10 is 0 cells away from the nearest pedestrian.
# Vehicle 10's gap distance from the leading vehicle is 0
#  jeep 10 is 0 cells away from the nearest vehicle.
#  jeep 10 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 10 needs to decelerate by 1
# jeep 10 has 0 before calling unloading method.
# jeep 10's passenger destinations areset()
# jeep 10: Unload Passengers? --- False
# jeep 10's passenger destinations areset()
# jeep 10 has 0 after calling unloading method.
# Vehicle 9's gap distance from the leading vehicle is 0
# Vehicle 9's gap distance from the leading vehicle is 1
# jeep 9 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 9's passenger destinations areset()
# jeep 9 calling attempt method.
# jeep 9 will try lane changing to the right lane
# jeep 9 has tried lane changing 0 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 9 checked a road portion with summed occupancy of 0.0
# Vehicle 9's gap distance from the leading vehicle is 0
# jeep 9 cannot straddle.
# jeep 9 has tried lane changing 1 times (incremented).
# jeep 9 attempted to load passengers. It attempted 1 times.
# jeep 9: Overshot a destination? --- False. Lane change trials  = 1
# jeep 9 has no passenger to be unloaded.
#  jeep 9 is inf cells away from the nearest destination.
#  jeep 9 is 0 cells away from the nearest pedestrian.
# Vehicle 9's gap distance from the leading vehicle is 0
#  jeep 9 is 0 cells away from the nearest vehicle.
#  jeep 9 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 9 needs to decelerate by 1
# jeep 9 has 0 before calling unloading method.
# jeep 9's passenger destinations areset()
# jeep 9: Unload Passengers? --- False
# jeep 9's passenger destinations areset()
# jeep 9 has 0 after calling unloading method.
# Vehicle 4's gap distance from the leading vehicle is 0
# Vehicle 4's gap distance from the leading vehicle is 1
# jeep 4 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 4's passenger destinations areset()
# jeep 4 calling attempt method.
# jeep 4 will try lane changing to the right lane
# jeep 4 has tried lane changing 0 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 4 checked a road portion with summed occupancy of 0.0
# Vehicle 4's gap distance from the leading vehicle is 0
# jeep 4 cannot straddle.
# jeep 4 has tried lane changing 1 times (incremented).
# jeep 4 attempted to load passengers. It attempted 1 times.
# jeep 4: Overshot a destination? --- False. Lane change trials  = 1
# jeep 4 has no passenger to be unloaded.
#  jeep 4 is inf cells away from the nearest destination.
#  jeep 4 is 0 cells away from the nearest pedestrian.
# Vehicle 4's gap distance from the leading vehicle is 0
#  jeep 4 is 0 cells away from the nearest vehicle.
#  jeep 4 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 4 needs to decelerate by 1
# jeep 4 has 0 before calling unloading method.
# jeep 4's passenger destinations areset()
# jeep 4: Unload Passengers? --- False
# jeep 4's passenger destinations areset()
# jeep 4 has 0 after calling unloading method.
# Vehicle 1's gap distance from the leading vehicle is 0
# Vehicle 1's gap distance from the leading vehicle is 1
# jeep 1 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 1's passenger destinations areset()
# jeep 1 calling attempt method.
# jeep 1 will try lane changing to the right lane
# jeep 1 has tried lane changing 0 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 1 checked a road portion with summed occupancy of 0.0
# Vehicle 1's gap distance from the leading vehicle is 0
# jeep 1 cannot straddle.
# jeep 1 has tried lane changing 1 times (incremented).
# jeep 1 attempted to load passengers. It attempted 1 times.
# jeep 1: Overshot a destination? --- False. Lane change trials  = 1
# jeep 1 has no passenger to be unloaded.
#  jeep 1 is inf cells away from the nearest destination.
#  jeep 1 is 0 cells away from the nearest pedestrian.
# Vehicle 1's gap distance from the leading vehicle is 0
#  jeep 1 is 0 cells away from the nearest vehicle.
#  jeep 1 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 1 needs to decelerate by 1
# jeep 1 has 0 before calling unloading method.
# jeep 1's passenger destinations areset()
# jeep 1: Unload Passengers? --- False
# jeep 1's passenger destinations areset()
# jeep 1 has 0 after calling unloading method.
# Vehicle 2's gap distance from the leading vehicle is 0
# Vehicle 2's gap distance from the leading vehicle is 1
# jeep 2 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 2's passenger destinations areset()
# jeep 2 calling attempt method.
# jeep 2 will try lane changing to the right lane
# jeep 2 has tried lane changing 0 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 2 checked a road portion with summed occupancy of 0.0
# Vehicle 2's gap distance from the leading vehicle is 0
# jeep 2 cannot straddle.
# jeep 2 has tried lane changing 1 times (incremented).
# jeep 2 attempted to load passengers. It attempted 1 times.
# jeep 2: Overshot a destination? --- False. Lane change trials  = 1
# jeep 2 has no passenger to be unloaded.
#  jeep 2 is inf cells away from the nearest destination.
#  jeep 2 is 0 cells away from the nearest pedestrian.
# Vehicle 2's gap distance from the leading vehicle is 0
#  jeep 2 is 0 cells away from the nearest vehicle.
#  jeep 2 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 2 needs to decelerate by 1
# jeep 2 has 0 before calling unloading method.
# jeep 2's passenger destinations areset()
# jeep 2: Unload Passengers? --- False
# jeep 2's passenger destinations areset()
# jeep 2 has 0 after calling unloading method.
# Vehicle 10's gap distance from the leading vehicle is 0
# Vehicle 10's gap distance from the leading vehicle is 1
# jeep 10 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 10's passenger destinations areset()
# jeep 10 calling attempt method.
# jeep 10 will try lane changing to the right lane
# jeep 10 has tried lane changing 1 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 10 checked a road portion with summed occupancy of 0.0
# Vehicle 10's gap distance from the leading vehicle is 0
# jeep 10 cannot straddle.
# jeep 10 has tried lane changing 2 times (incremented).
# jeep 10 attempted to load passengers. It attempted 2 times.
# jeep 10: Overshot a destination? --- False. Lane change trials  = 2
# jeep 10 has no passenger to be unloaded.
#  jeep 10 is inf cells away from the nearest destination.
#  jeep 10 is 0 cells away from the nearest pedestrian.
# Vehicle 10's gap distance from the leading vehicle is 0
#  jeep 10 is 0 cells away from the nearest vehicle.
#  jeep 10 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 10 needs to decelerate by 1
# jeep 10 has 0 before calling unloading method.
# jeep 10's passenger destinations areset()
# jeep 10: Unload Passengers? --- False
# jeep 10's passenger destinations areset()
# jeep 10 has 0 after calling unloading method.
# Vehicle 7's gap distance from the leading vehicle is 0
# Vehicle 7's gap distance from the leading vehicle is 1
# jeep 7 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 7's passenger destinations areset()
# jeep 7 calling attempt method.
# jeep 7 will try lane changing to the right lane
# jeep 7 has tried lane changing 1 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 7 checked a road portion with summed occupancy of 0.0
# Vehicle 7's gap distance from the leading vehicle is 0
# jeep 7 cannot straddle.
# jeep 7 has tried lane changing 2 times (incremented).
# jeep 7 attempted to load passengers. It attempted 2 times.
# jeep 7: Overshot a destination? --- False. Lane change trials  = 2
# jeep 7 has no passenger to be unloaded.
#  jeep 7 is inf cells away from the nearest destination.
#  jeep 7 is 0 cells away from the nearest pedestrian.
# Vehicle 7's gap distance from the leading vehicle is 0
#  jeep 7 is 0 cells away from the nearest vehicle.
#  jeep 7 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 7 needs to decelerate by 1
# jeep 7 has 0 before calling unloading method.
# jeep 7's passenger destinations areset()
# jeep 7: Unload Passengers? --- False
# jeep 7's passenger destinations areset()
# jeep 7 has 0 after calling unloading method.
# Vehicle 8's gap distance from the leading vehicle is 0
# Vehicle 8's gap distance from the leading vehicle is 1
# jeep 8 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 8's passenger destinations areset()
# jeep 8 calling attempt method.
# jeep 8 will try lane changing to the right lane
# jeep 8 has tried lane changing 1 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 8 checked a road portion with summed occupancy of 0.0
# Vehicle 8's gap distance from the leading vehicle is 0
# jeep 8 cannot straddle.
# jeep 8 has tried lane changing 2 times (incremented).
# jeep 8 attempted to load passengers. It attempted 2 times.
# jeep 8: Overshot a destination? --- False. Lane change trials  = 2
# jeep 8 has no passenger to be unloaded.
#  jeep 8 is inf cells away from the nearest destination.
#  jeep 8 is 0 cells away from the nearest pedestrian.
# Vehicle 8's gap distance from the leading vehicle is 0
#  jeep 8 is 0 cells away from the nearest vehicle.
#  jeep 8 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 8 needs to decelerate by 1
# jeep 8 has 0 before calling unloading method.
# jeep 8's passenger destinations areset()
# jeep 8: Unload Passengers? --- False
# jeep 8's passenger destinations areset()
# jeep 8 has 0 after calling unloading method.
# Vehicle 3's gap distance from the leading vehicle is 0
# Vehicle 3's gap distance from the leading vehicle is 1
# jeep 3 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 3's passenger destinations areset()
# jeep 3 calling attempt method.
# jeep 3 will try lane changing to the right lane
# jeep 3 has tried lane changing 1 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 3 checked a road portion with summed occupancy of 0.0
# Vehicle 3's gap distance from the leading vehicle is 0
# jeep 3 cannot straddle.
# jeep 3 has tried lane changing 2 times (incremented).
# jeep 3 attempted to load passengers. It attempted 2 times.
# jeep 3: Overshot a destination? --- False. Lane change trials  = 2
# jeep 3 has no passenger to be unloaded.
#  jeep 3 is inf cells away from the nearest destination.
#  jeep 3 is 0 cells away from the nearest pedestrian.
# Vehicle 3's gap distance from the leading vehicle is 0
#  jeep 3 is 0 cells away from the nearest vehicle.
#  jeep 3 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 3 needs to decelerate by 1
# jeep 3 has 0 before calling unloading method.
# jeep 3's passenger destinations areset()
# jeep 3: Unload Passengers? --- False
# jeep 3's passenger destinations areset()
# jeep 3 has 0 after calling unloading method.
# Vehicle 0's gap distance from the leading vehicle is 0
# Vehicle 0's gap distance from the leading vehicle is 1
# jeep 0 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 0's passenger destinations areset()
# jeep 0 calling attempt method.
# jeep 0 will try lane changing to the right lane
# jeep 0 has tried lane changing 1 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 0 checked a road portion with summed occupancy of 0.0
# Vehicle 0's gap distance from the leading vehicle is 0
# jeep 0 cannot straddle.
# jeep 0 has tried lane changing 2 times (incremented).
# jeep 0 attempted to load passengers. It attempted 2 times.
# jeep 0: Overshot a destination? --- False. Lane change trials  = 2
# jeep 0 has no passenger to be unloaded.
#  jeep 0 is inf cells away from the nearest destination.
#  jeep 0 is 0 cells away from the nearest pedestrian.
# Vehicle 0's gap distance from the leading vehicle is 0
#  jeep 0 is 0 cells away from the nearest vehicle.
#  jeep 0 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 0 needs to decelerate by 1
# jeep 0 has 0 before calling unloading method.
# jeep 0's passenger destinations areset()
# jeep 0: Unload Passengers? --- False
# jeep 0's passenger destinations areset()
# jeep 0 has 0 after calling unloading method.
# Vehicle 2's gap distance from the leading vehicle is 0
# Vehicle 2's gap distance from the leading vehicle is 1
# jeep 2 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 2's passenger destinations areset()
# jeep 2 calling attempt method.
# jeep 2 will try lane changing to the right lane
# jeep 2 has tried lane changing 1 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 2 checked a road portion with summed occupancy of 0.0
# Vehicle 2's gap distance from the leading vehicle is 0
# jeep 2 cannot straddle.
# jeep 2 has tried lane changing 2 times (incremented).
# jeep 2 attempted to load passengers. It attempted 2 times.
# jeep 2: Overshot a destination? --- False. Lane change trials  = 2
# jeep 2 has no passenger to be unloaded.
#  jeep 2 is inf cells away from the nearest destination.
#  jeep 2 is 0 cells away from the nearest pedestrian.
# Vehicle 2's gap distance from the leading vehicle is 0
#  jeep 2 is 0 cells away from the nearest vehicle.
#  jeep 2 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 2 needs to decelerate by 1
# jeep 2 has 0 before calling unloading method.
# jeep 2's passenger destinations areset()
# jeep 2: Unload Passengers? --- False
# jeep 2's passenger destinations areset()
# jeep 2 has 0 after calling unloading method.
# Vehicle 4's gap distance from the leading vehicle is 0
# Vehicle 4's gap distance from the leading vehicle is 1
# jeep 4 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 4's passenger destinations areset()
# jeep 4 calling attempt method.
# jeep 4 will try lane changing to the right lane
# jeep 4 has tried lane changing 1 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 4 checked a road portion with summed occupancy of 0.0
# Vehicle 4's gap distance from the leading vehicle is 0
# jeep 4 cannot straddle.
# jeep 4 has tried lane changing 2 times (incremented).
# jeep 4 attempted to load passengers. It attempted 2 times.
# jeep 4: Overshot a destination? --- False. Lane change trials  = 2
# jeep 4 has no passenger to be unloaded.
#  jeep 4 is inf cells away from the nearest destination.
#  jeep 4 is 0 cells away from the nearest pedestrian.
# Vehicle 4's gap distance from the leading vehicle is 0
#  jeep 4 is 0 cells away from the nearest vehicle.
#  jeep 4 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 4 needs to decelerate by 1
# jeep 4 has 0 before calling unloading method.
# jeep 4's passenger destinations areset()
# jeep 4: Unload Passengers? --- False
# jeep 4's passenger destinations areset()
# jeep 4 has 0 after calling unloading method.
# Vehicle 1's gap distance from the leading vehicle is 0
# Vehicle 1's gap distance from the leading vehicle is 1
# jeep 1 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 1's passenger destinations areset()
# jeep 1 calling attempt method.
# jeep 1 will try lane changing to the right lane
# jeep 1 has tried lane changing 1 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 1 checked a road portion with summed occupancy of 0.0
# Vehicle 1's gap distance from the leading vehicle is 0
# jeep 1 cannot straddle.
# jeep 1 has tried lane changing 2 times (incremented).
# jeep 1 attempted to load passengers. It attempted 2 times.
# jeep 1: Overshot a destination? --- False. Lane change trials  = 2
# jeep 1 has no passenger to be unloaded.
#  jeep 1 is inf cells away from the nearest destination.
#  jeep 1 is 0 cells away from the nearest pedestrian.
# Vehicle 1's gap distance from the leading vehicle is 0
#  jeep 1 is 0 cells away from the nearest vehicle.
#  jeep 1 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 1 needs to decelerate by 1
# jeep 1 has 0 before calling unloading method.
# jeep 1's passenger destinations areset()
# jeep 1: Unload Passengers? --- False
# jeep 1's passenger destinations areset()
# jeep 1 has 0 after calling unloading method.
# Vehicle 11's gap distance from the leading vehicle is 1
# Vehicle 11's gap distance from the leading vehicle is 1
# jeep 11 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 11's passenger destinations areset()
# jeep 11 calling attempt method.
# jeep 11 will try lane changing to the right lane
# jeep 11 has tried lane changing 1 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 11 checked a road portion with summed occupancy of 0.0
# Vehicle 11's gap distance from the leading vehicle is 1
# jeep 11 has tried lane changing 1 times (incremented).
# jeep 11 attempted to load passengers. It attempted 1 times.
# jeep 11: Overshot a destination? --- False. Lane change trials  = 1
# jeep 11 has no passenger to be unloaded.
#  jeep 11 is inf cells away from the nearest destination.
#  jeep 11 is 0 cells away from the nearest pedestrian.
# Vehicle 11's gap distance from the leading vehicle is 1
#  jeep 11 is 1 cells away from the nearest vehicle.
#  jeep 11 needs to decelerate by 1 to load passengers. Its current speed is 1 and target speed is 0
# jeep 11 needs to decelerate by 1
# jeep 11 has 0 before calling unloading method.
# jeep 11's passenger destinations areset()
# jeep 11: Unload Passengers? --- False
# jeep 11's passenger destinations areset()
# jeep 11 has 0 after calling unloading method.
# Vehicle 6's gap distance from the leading vehicle is 0
# Vehicle 6's gap distance from the leading vehicle is 1
# jeep 6 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 6's passenger destinations areset()
# jeep 6 calling attempt method.
# jeep 6 will try lane changing to the right lane
# jeep 6 has tried lane changing 1 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 6 checked a road portion with summed occupancy of 0.0
# Vehicle 6's gap distance from the leading vehicle is 0
# jeep 6 cannot straddle.
# jeep 6 has tried lane changing 2 times (incremented).
# jeep 6 attempted to load passengers. It attempted 2 times.
# jeep 6: Overshot a destination? --- False. Lane change trials  = 2
# jeep 6 has no passenger to be unloaded.
#  jeep 6 is inf cells away from the nearest destination.
#  jeep 6 is 0 cells away from the nearest pedestrian.
# Vehicle 6's gap distance from the leading vehicle is 0
#  jeep 6 is 0 cells away from the nearest vehicle.
#  jeep 6 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 6 needs to decelerate by 1
# jeep 6 has 0 before calling unloading method.
# jeep 6's passenger destinations areset()
# jeep 6: Unload Passengers? --- False
# jeep 6's passenger destinations areset()
# jeep 6 has 0 after calling unloading method.
# Vehicle 9's gap distance from the leading vehicle is 0
# Vehicle 9's gap distance from the leading vehicle is 1
# jeep 9 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 9's passenger destinations areset()
# jeep 9 calling attempt method.
# jeep 9 will try lane changing to the right lane
# jeep 9 has tried lane changing 1 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 9 checked a road portion with summed occupancy of 0.0
# Vehicle 9's gap distance from the leading vehicle is 0
# jeep 9 cannot straddle.
# jeep 9 has tried lane changing 2 times (incremented).
# jeep 9 attempted to load passengers. It attempted 2 times.
# jeep 9: Overshot a destination? --- False. Lane change trials  = 2
# jeep 9 has no passenger to be unloaded.
#  jeep 9 is inf cells away from the nearest destination.
#  jeep 9 is 0 cells away from the nearest pedestrian.
# Vehicle 9's gap distance from the leading vehicle is 0
#  jeep 9 is 0 cells away from the nearest vehicle.
#  jeep 9 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 9 needs to decelerate by 1
# jeep 9 has 0 before calling unloading method.
# jeep 9's passenger destinations areset()
# jeep 9: Unload Passengers? --- False
# jeep 9's passenger destinations areset()
# jeep 9 has 0 after calling unloading method.
# Vehicle 5's gap distance from the leading vehicle is 0
# Vehicle 5's gap distance from the leading vehicle is 1
# jeep 5 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 5's passenger destinations areset()
# jeep 5 calling attempt method.
# jeep 5 will try lane changing to the right lane
# jeep 5 has tried lane changing 1 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 5 checked a road portion with summed occupancy of 0.0
# Vehicle 5's gap distance from the leading vehicle is 0
# jeep 5 cannot straddle.
# jeep 5 has tried lane changing 2 times (incremented).
# jeep 5 attempted to load passengers. It attempted 2 times.
# jeep 5: Overshot a destination? --- False. Lane change trials  = 2
# jeep 5 has no passenger to be unloaded.
#  jeep 5 is inf cells away from the nearest destination.
#  jeep 5 is 0 cells away from the nearest pedestrian.
# Vehicle 5's gap distance from the leading vehicle is 0
#  jeep 5 is 0 cells away from the nearest vehicle.
#  jeep 5 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 5 needs to decelerate by 1
# jeep 5 has 0 before calling unloading method.
# jeep 5's passenger destinations areset()
# jeep 5: Unload Passengers? --- False
# jeep 5's passenger destinations areset()
# jeep 5 has 0 after calling unloading method.
# Vehicle 4's gap distance from the leading vehicle is 0
# Vehicle 4's gap distance from the leading vehicle is 1
# jeep 4 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 4's passenger destinations areset()
# jeep 4 calling attempt method.
# jeep 4 will try lane changing to the right lane
# jeep 4 has tried lane changing 2 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 4 checked a road portion with summed occupancy of 0.0
# Vehicle 4's gap distance from the leading vehicle is 0
# jeep 4 cannot straddle.
# jeep 4 has tried lane changing 3 times (incremented).
# jeep 4 attempted to load passengers. It attempted 3 times.
# jeep 4: Overshot a destination? --- False. Lane change trials  = 3
# jeep 4 has no passenger to be unloaded.
#  jeep 4 is inf cells away from the nearest destination.
#  jeep 4 is 0 cells away from the nearest pedestrian.
# Vehicle 4's gap distance from the leading vehicle is 0
#  jeep 4 is 0 cells away from the nearest vehicle.
#  jeep 4 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 4 needs to decelerate by 1
# jeep 4 has 0 before calling unloading method.
# jeep 4's passenger destinations areset()
# jeep 4: Unload Passengers? --- False
# jeep 4's passenger destinations areset()
# jeep 4 has 0 after calling unloading method.
# Vehicle 7's gap distance from the leading vehicle is 0
# Vehicle 7's gap distance from the leading vehicle is 1
# jeep 7 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 7's passenger destinations areset()
# jeep 7 calling attempt method.
# jeep 7 will try lane changing to the right lane
# jeep 7 has tried lane changing 2 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 7 checked a road portion with summed occupancy of 0.0
# Vehicle 7's gap distance from the leading vehicle is 0
# jeep 7 cannot straddle.
# jeep 7 has tried lane changing 3 times (incremented).
# jeep 7 attempted to load passengers. It attempted 3 times.
# jeep 7: Overshot a destination? --- False. Lane change trials  = 3
# jeep 7 has no passenger to be unloaded.
#  jeep 7 is inf cells away from the nearest destination.
#  jeep 7 is 0 cells away from the nearest pedestrian.
# Vehicle 7's gap distance from the leading vehicle is 0
#  jeep 7 is 0 cells away from the nearest vehicle.
#  jeep 7 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 7 needs to decelerate by 1
# jeep 7 has 0 before calling unloading method.
# jeep 7's passenger destinations areset()
# jeep 7: Unload Passengers? --- False
# jeep 7's passenger destinations areset()
# jeep 7 has 0 after calling unloading method.
# Vehicle 0's gap distance from the leading vehicle is 0
# Vehicle 0's gap distance from the leading vehicle is 1
# jeep 0 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 0's passenger destinations areset()
# jeep 0 calling attempt method.
# jeep 0 will try lane changing to the right lane
# jeep 0 has tried lane changing 2 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 0 checked a road portion with summed occupancy of 0.0
# Vehicle 0's gap distance from the leading vehicle is 0
# jeep 0 cannot straddle.
# jeep 0 has tried lane changing 3 times (incremented).
# jeep 0 attempted to load passengers. It attempted 3 times.
# jeep 0: Overshot a destination? --- False. Lane change trials  = 3
# jeep 0 has no passenger to be unloaded.
#  jeep 0 is inf cells away from the nearest destination.
#  jeep 0 is 0 cells away from the nearest pedestrian.
# Vehicle 0's gap distance from the leading vehicle is 0
#  jeep 0 is 0 cells away from the nearest vehicle.
#  jeep 0 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 0 needs to decelerate by 1
# jeep 0 has 0 before calling unloading method.
# jeep 0's passenger destinations areset()
# jeep 0: Unload Passengers? --- False
# jeep 0's passenger destinations areset()
# jeep 0 has 0 after calling unloading method.
# Vehicle 1's gap distance from the leading vehicle is 0
# Vehicle 1's gap distance from the leading vehicle is 1
# jeep 1 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 1's passenger destinations areset()
# jeep 1 calling attempt method.
# jeep 1 will try lane changing to the right lane
# jeep 1 has tried lane changing 2 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 1 checked a road portion with summed occupancy of 0.0
# Vehicle 1's gap distance from the leading vehicle is 0
# jeep 1 cannot straddle.
# jeep 1 has tried lane changing 3 times (incremented).
# jeep 1 attempted to load passengers. It attempted 3 times.
# jeep 1: Overshot a destination? --- False. Lane change trials  = 3
# jeep 1 has no passenger to be unloaded.
#  jeep 1 is inf cells away from the nearest destination.
#  jeep 1 is 0 cells away from the nearest pedestrian.
# Vehicle 1's gap distance from the leading vehicle is 0
#  jeep 1 is 0 cells away from the nearest vehicle.
#  jeep 1 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 1 needs to decelerate by 1
# jeep 1 has 0 before calling unloading method.
# jeep 1's passenger destinations areset()
# jeep 1: Unload Passengers? --- False
# jeep 1's passenger destinations areset()
# jeep 1 has 0 after calling unloading method.
# Vehicle 8's gap distance from the leading vehicle is 0
# Vehicle 8's gap distance from the leading vehicle is 1
# jeep 8 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 8's passenger destinations areset()
# jeep 8 calling attempt method.
# jeep 8 will try lane changing to the right lane
# jeep 8 has tried lane changing 2 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 8 checked a road portion with summed occupancy of 0.0
# Vehicle 8's gap distance from the leading vehicle is 0
# jeep 8 cannot straddle.
# jeep 8 has tried lane changing 3 times (incremented).
# jeep 8 attempted to load passengers. It attempted 3 times.
# jeep 8: Overshot a destination? --- False. Lane change trials  = 3
# jeep 8 has no passenger to be unloaded.
#  jeep 8 is inf cells away from the nearest destination.
#  jeep 8 is 0 cells away from the nearest pedestrian.
# Vehicle 8's gap distance from the leading vehicle is 0
#  jeep 8 is 0 cells away from the nearest vehicle.
#  jeep 8 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 8 needs to decelerate by 1
# jeep 8 has 0 before calling unloading method.
# jeep 8's passenger destinations areset()
# jeep 8: Unload Passengers? --- False
# jeep 8's passenger destinations areset()
# jeep 8 has 0 after calling unloading method.
# Vehicle 6's gap distance from the leading vehicle is 0
# Vehicle 6's gap distance from the leading vehicle is 1
# jeep 6 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 6's passenger destinations areset()
# jeep 6 calling attempt method.
# jeep 6 will try lane changing to the right lane
# jeep 6 has tried lane changing 2 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 6 checked a road portion with summed occupancy of 0.0
# Vehicle 6's gap distance from the leading vehicle is 0
# jeep 6 cannot straddle.
# jeep 6 has tried lane changing 3 times (incremented).
# jeep 6 attempted to load passengers. It attempted 3 times.
# jeep 6: Overshot a destination? --- False. Lane change trials  = 3
# jeep 6 has no passenger to be unloaded.
#  jeep 6 is inf cells away from the nearest destination.
#  jeep 6 is 0 cells away from the nearest pedestrian.
# Vehicle 6's gap distance from the leading vehicle is 0
#  jeep 6 is 0 cells away from the nearest vehicle.
#  jeep 6 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 6 needs to decelerate by 1
# jeep 6 has 0 before calling unloading method.
# jeep 6's passenger destinations areset()
# jeep 6: Unload Passengers? --- False
# jeep 6's passenger destinations areset()
# jeep 6 has 0 after calling unloading method.
# jeep 11 has no passenger to be unloaded.
#  jeep 11 is inf cells away from the nearest destination.
#  jeep 11 is 0 cells away from the nearest pedestrian.
# Vehicle 11's gap distance from the leading vehicle is 0
#  jeep 11 is 0 cells away from the nearest vehicle.
#  jeep 11 needs to decelerate by 0 to avoid collisions. Its current speed is 0 and target speed is 0
# Vehicle 10's gap distance from the leading vehicle is 1
# Vehicle 10's gap distance from the leading vehicle is 1
# jeep 10 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 10's passenger destinations areset()
# jeep 10 calling attempt method.
# jeep 10 will try lane changing to the right lane
# jeep 10 has tried lane changing 2 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 10 checked a road portion with summed occupancy of 1.0
# jeep 10 attempted to load passengers. It attempted 2 times.
# jeep 10: Overshot a destination? --- False. Lane change trials  = 2
# jeep 10 has no passenger to be unloaded.
#  jeep 10 is inf cells away from the nearest destination.
#  jeep 10 is 0 cells away from the nearest pedestrian.
# Vehicle 10's gap distance from the leading vehicle is 1
#  jeep 10 is 1 cells away from the nearest vehicle.
#  jeep 10 needs to decelerate by 1 to load passengers. Its current speed is 1 and target speed is 0
# jeep 10 needs to decelerate by 1
# jeep 10 has 0 before calling unloading method.
# jeep 10's passenger destinations areset()
# jeep 10: Unload Passengers? --- False
# jeep 10's passenger destinations areset()
# jeep 10 has 0 after calling unloading method.
# Vehicle 12's gap distance from the leading vehicle is 2
# Vehicle 12's gap distance from the leading vehicle is 2
# jeep 12 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 12's passenger destinations areset()
# jeep 12 calling attempt method.
# jeep 12 already on Lane 1.
# jeep 12 attempted to load passengers. It attempted 1 times.
# jeep 12: Overshot a destination? --- False. Lane change trials  = 1
# jeep 12 has no passenger to be unloaded.
#  jeep 12 is inf cells away from the nearest destination.
#  jeep 12 is 0 cells away from the nearest pedestrian.
# Vehicle 12's gap distance from the leading vehicle is 2
#  jeep 12 is 2 cells away from the nearest vehicle.
#  jeep 12 needs to decelerate by 2 to load passengers. Its current speed is 2 and target speed is 0
# jeep 12 needs to decelerate by 2
# jeep 12 has 0 before calling unloading method.
# jeep 12's passenger destinations areset()
# jeep 12: Unload Passengers? --- False
# jeep 12's passenger destinations areset()
# jeep 12 has 0 after calling unloading method.
# Vehicle 2's gap distance from the leading vehicle is 0
# Vehicle 2's gap distance from the leading vehicle is 1
# jeep 2 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 2's passenger destinations areset()
# jeep 2 calling attempt method.
# jeep 2 will try lane changing to the right lane
# jeep 2 has tried lane changing 2 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 2 checked a road portion with summed occupancy of 0.0
# Vehicle 2's gap distance from the leading vehicle is 0
# jeep 2 cannot straddle.
# jeep 2 has tried lane changing 3 times (incremented).
# jeep 2 attempted to load passengers. It attempted 3 times.
# jeep 2: Overshot a destination? --- False. Lane change trials  = 3
# jeep 2 has no passenger to be unloaded.
#  jeep 2 is inf cells away from the nearest destination.
#  jeep 2 is 0 cells away from the nearest pedestrian.
# Vehicle 2's gap distance from the leading vehicle is 0
#  jeep 2 is 0 cells away from the nearest vehicle.
#  jeep 2 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 2 needs to decelerate by 1
# jeep 2 has 0 before calling unloading method.
# jeep 2's passenger destinations areset()
# jeep 2: Unload Passengers? --- False
# jeep 2's passenger destinations areset()
# jeep 2 has 0 after calling unloading method.
# Vehicle 5's gap distance from the leading vehicle is 0
# Vehicle 5's gap distance from the leading vehicle is 1
# jeep 5 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 5's passenger destinations areset()
# jeep 5 calling attempt method.
# jeep 5 will try lane changing to the right lane
# jeep 5 has tried lane changing 2 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 5 checked a road portion with summed occupancy of 0.0
# Vehicle 5's gap distance from the leading vehicle is 0
# jeep 5 cannot straddle.
# jeep 5 has tried lane changing 3 times (incremented).
# jeep 5 attempted to load passengers. It attempted 3 times.
# jeep 5: Overshot a destination? --- False. Lane change trials  = 3
# jeep 5 has no passenger to be unloaded.
#  jeep 5 is inf cells away from the nearest destination.
#  jeep 5 is 0 cells away from the nearest pedestrian.
# Vehicle 5's gap distance from the leading vehicle is 0
#  jeep 5 is 0 cells away from the nearest vehicle.
#  jeep 5 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 5 needs to decelerate by 1
# jeep 5 has 0 before calling unloading method.
# jeep 5's passenger destinations areset()
# jeep 5: Unload Passengers? --- False
# jeep 5's passenger destinations areset()
# jeep 5 has 0 after calling unloading method.
# Vehicle 9's gap distance from the leading vehicle is 0
# Vehicle 9's gap distance from the leading vehicle is 1
# jeep 9 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 9's passenger destinations areset()
# jeep 9 calling attempt method.
# jeep 9 will try lane changing to the right lane
# jeep 9 has tried lane changing 2 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 9 checked a road portion with summed occupancy of 0.0
# Vehicle 9's gap distance from the leading vehicle is 0
# jeep 9 cannot straddle.
# jeep 9 has tried lane changing 3 times (incremented).
# jeep 9 attempted to load passengers. It attempted 3 times.
# jeep 9: Overshot a destination? --- False. Lane change trials  = 3
# jeep 9 has no passenger to be unloaded.
# ...
#  jeep 5 is inf cells away from the nearest destination.
#  jeep 5 is 0 cells away from the nearest pedestrian.
# Vehicle 5's gap distance from the leading vehicle is 0
#  jeep 5 is 0 cells away from the nearest vehicle.
#  jeep 5 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 5 needs to decelerate by 1
# jeep 5 has 4 before calling unloading method.
# jeep 5's passenger destinations areset()
# jeep 5: Unload Passengers? --- False
# jeep 5's passenger destinations areset()
# jeep 5 has 4 after calling unloading method.
# Vehicle 10's gap distance from the leading vehicle is 1
# Vehicle 10's gap distance from the leading vehicle is 2
# jeep 10 is calling lane changing method. The numbers of passengers within vehicle is 0. The passengers ARE []
# jeep 10's passenger destinations areset()
# jeep 10 calling attempt method.
# jeep 10 already on Lane 1.
# jeep 10 attempted to load passengers. It attempted 1 times.
# jeep 10: Overshot a destination? --- False. Lane change trials  = 1
# jeep 10 has no passenger to be unloaded.
#  jeep 10 is inf cells away from the nearest destination.
#  jeep 10 is 0 cells away from the nearest pedestrian.
# Vehicle 10's gap distance from the leading vehicle is 1
#  jeep 10 is 1 cells away from the nearest vehicle.
#  jeep 10 needs to decelerate by 2 to load passengers. Its current speed is 2 and target speed is 0
# jeep 10 needs to decelerate by 2
# jeep 10 has 0 before calling unloading method.
# jeep 10's passenger destinations areset()
# jeep 10: Unload Passengers? --- False
# jeep 10's passenger destinations areset()
# jeep 10 has 0 after calling unloading method.
# Vehicle 9's gap distance from the leading vehicle is 1
# Vehicle 9's gap distance from the leading vehicle is 0
# jeep 9 is calling lane changing method. The numbers of passengers within vehicle is 3. The passengers ARE [<passenger.Passenger object at 0x74ae58d46e50>, <passenger.Passenger object at 0x74adc0dfab90>, <passenger.Passenger object at 0x74add21584d0>]
# jeep 9's passenger destinations areset()
# jeep 9 calling attempt method.
# jeep 9 will try lane changing to the right lane
# jeep 9 has tried lane changing 0 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 9 checked a road portion with summed occupancy of 3.0
# jeep 9 attempted to load passengers. It attempted 0 times.
# jeep 9: Overshot a destination? --- False. Lane change trials  = 0
# Passenger 27's riding status is chilling
# Passenger 62's riding status is chilling
# Passenger 84's riding status is chilling
# jeep 9 has no passenger to be unloaded.
#  jeep 9 is inf cells away from the nearest destination.
#  jeep 9 is 0 cells away from the nearest pedestrian.
# Vehicle 9's gap distance from the leading vehicle is 1
#  jeep 9 is 1 cells away from the nearest vehicle.
#  jeep 9 needs to decelerate by 1 to load passengers. Its current speed is 1 and target speed is 0
# jeep 9 needs to decelerate by 1
# jeep 9 has 3 before calling unloading method.
# jeep 9's passenger destinations areset()
# jeep 9: Unload Passengers? --- False
# jeep 9's passenger destinations areset()
# jeep 9 has 3 after calling unloading method.
# Vehicle 8's gap distance from the leading vehicle is 0
# Vehicle 8's gap distance from the leading vehicle is 1
# jeep 8 is calling lane changing method. The numbers of passengers within vehicle is 4. The passengers ARE [<passenger.Passenger object at 0x74ae5a173110>, <passenger.Passenger object at 0x74adf3ff9c10>, <passenger.Passenger object at 0x74adc0dc7050>, <passenger.Passenger object at 0x74adaf914f90>]
# jeep 8's passenger destinations areset()
# jeep 8 calling attempt method.
# jeep 8 will try lane changing to the right lane
# jeep 8 has tried lane changing 2 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 8 checked a road portion with summed occupancy of 0.0
# Vehicle 8's gap distance from the leading vehicle is 0
# jeep 8 cannot straddle.
# jeep 8 has tried lane changing 3 times (incremented).
# jeep 8 attempted to load passengers. It attempted 3 times.
# jeep 8: Overshot a destination? --- False. Lane change trials  = 3
# Passenger 24's riding status is chilling
# Passenger 61's riding status is chilling
# Passenger 83's riding status is chilling
# Passenger 98's riding status is chilling
# jeep 8 has no passenger to be unloaded.
#  jeep 8 is inf cells away from the nearest destination.
#  jeep 8 is 0 cells away from the nearest pedestrian.
# Vehicle 8's gap distance from the leading vehicle is 0
#  jeep 8 is 0 cells away from the nearest vehicle.
#  jeep 8 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 8 needs to decelerate by 1
# jeep 8 has 4 before calling unloading method.
# jeep 8's passenger destinations areset()
# jeep 8: Unload Passengers? --- False
# jeep 8's passenger destinations areset()
# jeep 8 has 4 after calling unloading method.
# Vehicle 2's gap distance from the leading vehicle is 0
# Vehicle 2's gap distance from the leading vehicle is 1
# jeep 2 is calling lane changing method. The numbers of passengers within vehicle is 4. The passengers ARE [<passenger.Passenger object at 0x74ae64d27750>, <passenger.Passenger object at 0x74adc97f62d0>, <passenger.Passenger object at 0x74adb83a4490>, <passenger.Passenger object at 0x74add21cd610>]
# jeep 2's passenger destinations areset()
# jeep 2 calling attempt method.
# jeep 2 will try lane changing to the right lane
# jeep 2 has tried lane changing 3 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 2 checked a road portion with summed occupancy of 0.0
# Vehicle 2's gap distance from the leading vehicle is 0
# jeep 2 cannot straddle.
# jeep 2 has tried lane changing 4 times (incremented).
# jeep 2 attempted to load passengers. It attempted 4 times.
# jeep 2: Overshot a destination? --- False. Lane change trials  = 4
# Passenger 6's riding status is chilling
# Passenger 55's riding status is chilling
# Passenger 77's riding status is chilling
# Passenger 92's riding status is chilling
# jeep 2 has no passenger to be unloaded.
#  jeep 2 is inf cells away from the nearest destination.
#  jeep 2 is 0 cells away from the nearest pedestrian.
# Vehicle 2's gap distance from the leading vehicle is 0
#  jeep 2 is 0 cells away from the nearest vehicle.
#  jeep 2 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 2 needs to decelerate by 1
# jeep 2 has 4 before calling unloading method.
# jeep 2's passenger destinations areset()
# jeep 2: Unload Passengers? --- False
# jeep 2's passenger destinations areset()
# jeep 2 has 4 after calling unloading method.
# Vehicle 11's gap distance from the leading vehicle is 2
# Vehicle 11's gap distance from the leading vehicle is 2
# jeep 11 is calling lane changing method. The numbers of passengers within vehicle is 20. The passengers ARE [<passenger.Passenger object at 0x74ae657f3a10>, <passenger.Passenger object at 0x74ae58d47350>, <passenger.Passenger object at 0x74ae58d47450>, <passenger.Passenger object at 0x74adaf997190>, <passenger.Passenger object at 0x74ada6fbee50>, <passenger.Passenger object at 0x74ada6fbd790>, <passenger.Passenger object at 0x74adaf9cf090>, <passenger.Passenger object at 0x74ae5816bad0>, <passenger.Passenger object at 0x74add217e510>, <passenger.Passenger object at 0x74add2182b10>, <passenger.Passenger object at 0x74adf3f2ef90>, <passenger.Passenger object at 0x74adaf916550>, <passenger.Passenger object at 0x74adf3ff36d0>, <passenger.Passenger object at 0x74adf3f37c90>, <passenger.Passenger object at 0x74adf3f06fd0>, <passenger.Passenger object at 0x74addabc9b50>, <passenger.Passenger object at 0x74ade3542690>, <passenger.Passenger object at 0x74ae64d26310>, <passenger.Passenger object at 0x74adc972a0d0>, <passenger.Passenger object at 0x74ade353cbd0>]
# jeep 11's passenger destinations areset()
# jeep 11: Overshot a destination? --- False. Lane change trials  = 1
# Passenger 35's riding status is chilling
# Passenger 36's riding status is chilling
# Passenger 37's riding status is chilling
# Passenger 100's riding status is chilling
# Passenger 101's riding status is chilling
# Passenger 102's riding status is chilling
# Passenger 103's riding status is chilling
# Passenger 104's riding status is chilling
# Passenger 105's riding status is chilling
# Passenger 106's riding status is chilling
# Passenger 107's riding status is chilling
# Passenger 108's riding status is chilling
# Passenger 109's riding status is chilling
# Passenger 110's riding status is chilling
# Passenger 111's riding status is chilling
# Passenger 116's riding status is chilling
# Passenger 117's riding status is chilling
# Passenger 118's riding status is chilling
# Passenger 120's riding status is chilling
# Passenger 121's riding status is chilling
# jeep 11 has no passenger to be unloaded.
#  jeep 11 is inf cells away from the nearest destination.
#  jeep 11 is 0 cells away from the nearest pedestrian.
# Vehicle 11's gap distance from the leading vehicle is 2
#  jeep 11 is 2 cells away from the nearest vehicle.
#  jeep 11 needs to decelerate by 0 to avoid collisions. Its current speed is 2 and target speed is 2
# jeep 11 has 20 before calling unloading method.
# jeep 11's passenger destinations areset()
# jeep 11: Unload Passengers? --- False
# jeep 11's passenger destinations areset()
# jeep 11 has 20 after calling unloading method.
# Vehicle 0's gap distance from the leading vehicle is 0
# Vehicle 0's gap distance from the leading vehicle is 1
# jeep 0 is calling lane changing method. The numbers of passengers within vehicle is 4. The passengers ARE [<passenger.Passenger object at 0x74ae58d46850>, <passenger.Passenger object at 0x74adc0df8850>, <passenger.Passenger object at 0x74ade3583b50>, <passenger.Passenger object at 0x74adc0de3590>]
# jeep 0's passenger destinations areset()
# jeep 0 calling attempt method.
# jeep 0 will try lane changing to the right lane
# jeep 0 has tried lane changing 1 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 0 checked a road portion with summed occupancy of 0.0
# Vehicle 0's gap distance from the leading vehicle is 0
# jeep 0 cannot straddle.
# jeep 0 has tried lane changing 2 times (incremented).
# jeep 0 attempted to load passengers. It attempted 2 times.
# jeep 0: Overshot a destination? --- False. Lane change trials  = 2
# Passenger 0's riding status is chilling
# Passenger 53's riding status is chilling
# Passenger 75's riding status is chilling
# Passenger 90's riding status is chilling
# jeep 0 has no passenger to be unloaded.
#  jeep 0 is inf cells away from the nearest destination.
#  jeep 0 is 0 cells away from the nearest pedestrian.
# Vehicle 0's gap distance from the leading vehicle is 0
#  jeep 0 is 0 cells away from the nearest vehicle.
#  jeep 0 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 0 needs to decelerate by 1
# jeep 0 has 4 before calling unloading method.
# jeep 0's passenger destinations areset()
# jeep 0: Unload Passengers? --- False
# jeep 0's passenger destinations areset()
# jeep 0 has 4 after calling unloading method.
# Vehicle 1's gap distance from the leading vehicle is 0
# Vehicle 1's gap distance from the leading vehicle is 1
# jeep 1 is calling lane changing method. The numbers of passengers within vehicle is 4. The passengers ARE [<passenger.Passenger object at 0x74ae700b4f90>, <passenger.Passenger object at 0x74ade359c050>, <passenger.Passenger object at 0x74ad9e57ecd0>, <passenger.Passenger object at 0x74adf3f22ed0>]
# jeep 1's passenger destinations areset()
# jeep 1 calling attempt method.
# jeep 1 will try lane changing to the right lane
# jeep 1 has tried lane changing 2 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 1 checked a road portion with summed occupancy of 0.0
# Vehicle 1's gap distance from the leading vehicle is 0
# jeep 1 cannot straddle.
# jeep 1 has tried lane changing 3 times (incremented).
# jeep 1 attempted to load passengers. It attempted 3 times.
# jeep 1: Overshot a destination? --- False. Lane change trials  = 3
# Passenger 3's riding status is chilling
# Passenger 54's riding status is chilling
# Passenger 76's riding status is chilling
# Passenger 91's riding status is chilling
# jeep 1 has no passenger to be unloaded.
#  jeep 1 is inf cells away from the nearest destination.
#  jeep 1 is 0 cells away from the nearest pedestrian.
# Vehicle 1's gap distance from the leading vehicle is 0
#  jeep 1 is 0 cells away from the nearest vehicle.
#  jeep 1 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 1 needs to decelerate by 1
# jeep 1 has 4 before calling unloading method.
# jeep 1's passenger destinations areset()
# jeep 1: Unload Passengers? --- False
# jeep 1's passenger destinations areset()
# jeep 1 has 4 after calling unloading method.
# Vehicle 3's gap distance from the leading vehicle is 0
# Vehicle 3's gap distance from the leading vehicle is 1
# jeep 3 is calling lane changing method. The numbers of passengers within vehicle is 4. The passengers ARE [<passenger.Passenger object at 0x74ae7079b9d0>, <passenger.Passenger object at 0x74adc0d32e50>, <passenger.Passenger object at 0x74ad9e57c4d0>, <passenger.Passenger object at 0x74addabc6dd0>]
# jeep 3's passenger destinations areset()
# jeep 3 calling attempt method.
# jeep 3 will try lane changing to the right lane
# jeep 3 has tried lane changing 1 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 3 checked a road portion with summed occupancy of 0.0
# Vehicle 3's gap distance from the leading vehicle is 0
# jeep 3 cannot straddle.
# jeep 3 has tried lane changing 2 times (incremented).
# jeep 3 attempted to load passengers. It attempted 2 times.
# jeep 3: Overshot a destination? --- False. Lane change trials  = 2
# Passenger 9's riding status is chilling
# Passenger 56's riding status is chilling
# Passenger 78's riding status is chilling
# Passenger 93's riding status is chilling
# jeep 3 has no passenger to be unloaded.
#  jeep 3 is inf cells away from the nearest destination.
#  jeep 3 is 0 cells away from the nearest pedestrian.
# Vehicle 3's gap distance from the leading vehicle is 0
#  jeep 3 is 0 cells away from the nearest vehicle.
#  jeep 3 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 3 needs to decelerate by 1
# jeep 3 has 4 before calling unloading method.
# jeep 3's passenger destinations areset()
# jeep 3: Unload Passengers? --- False
# jeep 3's passenger destinations areset()
# jeep 3 has 4 after calling unloading method.
# Vehicle 7's gap distance from the leading vehicle is 0
# Vehicle 7's gap distance from the leading vehicle is 1
# jeep 7 is calling lane changing method. The numbers of passengers within vehicle is 4. The passengers ARE [<passenger.Passenger object at 0x74ae58d46ad0>, <passenger.Passenger object at 0x74ad9e5aa7d0>, <passenger.Passenger object at 0x74ad9e57eb50>, <passenger.Passenger object at 0x74addab7eb10>]
# jeep 7's passenger destinations areset()
# jeep 7 calling attempt method.
# jeep 7 will try lane changing to the right lane
# jeep 7 has tried lane changing 3 times.
# Lane change on row 0 is allowed. Will try doing so.
# jeep 7 checked a road portion with summed occupancy of 0.0
# Vehicle 7's gap distance from the leading vehicle is 0
# jeep 7 cannot straddle.
# jeep 7 has tried lane changing 4 times (incremented).
# jeep 7 attempted to load passengers. It attempted 4 times.
# jeep 7: Overshot a destination? --- False. Lane change trials  = 4
# Passenger 21's riding status is chilling
# Passenger 60's riding status is chilling
# Passenger 82's riding status is chilling
# Passenger 97's riding status is chilling
# jeep 7 has no passenger to be unloaded.
#  jeep 7 is inf cells away from the nearest destination.
#  jeep 7 is 0 cells away from the nearest pedestrian.
# Vehicle 7's gap distance from the leading vehicle is 0
#  jeep 7 is 0 cells away from the nearest vehicle.
#  jeep 7 needs to decelerate by 1 to avoid collisions. Its current speed is 1 and target speed is 0
# jeep 7 needs to decelerate by 1
# jeep 7 has 4 before calling unloading method.
# jeep 7's passenger destinations areset()
# jeep 7: Unload Passengers? --- False
# jeep 7's passenger destinations areset()
# jeep 7 has 4 after calling unloading method.

# %%
#Animated
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig, ax = plt.subplots()

def update(frame):
    ax.clear()
    integrated_simulator.visualize_combined(frame)  # This function should update the figure instead of replotting everything
    ax.set_title(f"Timestep: {frame}")

def animate_simulation():
    ani = animation.FuncAnimation(fig, update, frames=max_timesteps, repeat=False)
    plt.show()

# Run the simulation
max_timesteps = 1000  # Set your desired number of timesteps
jeepney_allowed_rows = [2] #allowed rows for initialization
truck_allowed_rows = [0, 2]  #allowed rows for initialization
integrated_simulator.run_simulation(max_timesteps, truck_lane_change_prob=1, jeep_lane_change_prob=1,
                          transient_time=30, density=0.3, truck_fraction=0, 
                          stop_to_stop_distance=1, safe_stopping_speed=2.0, safe_deceleration=2.0,
                          jeepney_allowed_rows=jeepney_allowed_rows , truck_allowed_rows=truck_allowed_rows, visualize=True)

# Start the animation
animate_simulation()

# %% [markdown]
# Run Multiple Trials

# %%
import os
import pandas as pd

# Define the base directory (one level above the notebook folder)
base_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))  # Moves one directory up

# Define folder names outside the notebook folder
folders = ["VehicleData_test", "TimestepSummary_test", "PassengerData_test", "Spatio-Temporal_test"]
folder_paths = {folder: os.path.join(base_dir, folder) for folder in folders}

# Ensure directories exist
for path in folder_paths.values():
    os.makedirs(path, exist_ok=True)

# Number of trials
num_trials = 1
density = 0.4
truck_fraction = 0.2
# Loop over trials
for trial in range(1, num_trials + 1):
    # Generate dummy DataFrames (replace with actual simulation data)
     
    timestep_summary, passenger_data, vehicle_data, spatio_temporal = integrated_simulator.run_simulation(6000, 1, 1, 1000, density, truck_fraction, 1,safe_stopping_speed, safe_deceleration, jeepney_allowed_rows, truck_allowed_rows, visualize=False)

    # File paths (outside notebook
    # File paths (outside the notebook folder)
    vehicle_file = os.path.join(folder_paths["VehicleData_test"], f"Trial_{trial}Mar2(density = {density}, truck_fraction = {truck_fraction}).csv")
    timestep_file = os.path.join(folder_paths["TimestepSummary_test"], f"Trial_{trial}Mar2(density = {density}), truck_fraction = {truck_fraction}.csv")
    passenger_file = os.path.join(folder_paths["PassengerData_test"], f"Trial_{trial}Mar2(density = {density}), truck_fraction = {truck_fraction}.csv")
    spatio_temporal_file = os.path.join(folder_paths["Spatio-Temporal_test"], f"Trial{trial}Mar2(density = {density}), truck_fraction = {truck_fraction}.csv")
    # Save CSV files
    vehicle_data.to_csv(vehicle_file, index=False)
    timestep_summary.to_csv(timestep_file, index=False)
    passenger_data.to_csv(passenger_file, index=False)
    spatio_temporal.to_csv(spatio_temporal_file, index = False)

    print(f"Saved Trial {trial} data.")

print("All trials completed successfully.")
